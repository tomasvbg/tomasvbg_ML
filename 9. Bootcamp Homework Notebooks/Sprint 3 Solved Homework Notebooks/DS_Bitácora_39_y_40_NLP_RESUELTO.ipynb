# %% [markdown]
# # Natural Languaje Processing

# %% [markdown]
# ### Resumen personal de los principales conceptos de Natural Language Processing

# %% [markdown]
# - El procesamiento del lenguaje natural nos permite procesar lenguaje a partir de datos no estrucurados (palabras). Data-->NLP-->models.
#
# ***
#
# `NLP workflow`
#
# obtención de datos-->normalization-->vectorization-->modelos.
#
# `- 1. Obtención de datos`
#
# `- 2. Normalización:`
# Llevar todo el texto a un formato común donde palabras escritas de manera distinta o con significados similares se representen de la misma manera.
#
#     - 2.1 `pasar a minusculas` (.lower)
#
#     - 2.2 `tokenizar:`
#         - 2.2.1 tokenizar `texto`: pasar de un string de texto a una lista de de oraciones (nltk.tokenize.sent_tokenize(texto))
#         - 2.2.2 tokenizar `palabras`: pasar de un string de textos a una lista de palabras, puntuaciones, símbolos (nltk.tokenize.word_tokenize(texto))
#
#     - 2.3 `limpiar caracteres`: nos quedamos solo con los caracteres de nuestro interés (import re; re.sub("[â-zA-Z","", str(texto)"]"))
#         - expresiones regulares: secuencia de caracteres que especifica un patron de búsqueda.
#
#     - 2.4 `llevar a raiz`: lleva palabras distintas con significados similares a una forma común.
#         - `Stemmizar`: recorta palabras mediante un proceso heuristico. Fácil de usar pero no certero.
#         - `Lemmatizar`: utiliza un vocabulario para realizar un análisi morfológico. Precisa que además de la palara se le informe cuál es la función de la palabra en el texto (noubm verb, determiner, conjunction, adverb, adjective, etc....) (from nltk.stem import WordNetLemmatizer; wordnet_lemmatizer = WordNetLemmatizer(); wordnet_lemmatizer.lemmatize(palabra, get_wordnet_pos(palabra)).
#             - eg: ["was", "running", "hours"] ---> ["be", "run", "hour"]
#
# `- 3. Vectorización:` representar cada texto como un vector que podamos usar para entrenar nuestros modelos.
#     - `Bag of words`: genera un vector que represente todas las palabras del corpus. Representa cada instancia como un vector con la cantidad de veces que aparecen las palabras. Cada palabra es un feature, y cada documento es una fila. Cada cruce feature/document en la matriz, representa la cantidad de veces que esa palabra aparece en el documento.
#     - `Encoders`:
#     - `Word embeddings`:
#
# `-4.Modelamiento:``
#     - naive bayes
#     - SVD
#     - decission tree
#     - ...
#
#
# ***
#
# `Conceptos relevantes`
#
# - `punkt`: palabras ofensoras(nltk.download("punkt")
#
# - `stopwords`: diccionario de palabras a no considerar en el análisis(nltk.download("stopwords")
#
# ***
#
# `TF e IDF`
#
# - Hay palabras que cobran sentido cuando se agrupan con otras (eg. plaza italia, control remoto)
#
# `N-grama`
#     - la solución a este problema son los n-gramas.
#      - un N-Grama nos permite calcular las diferentes combinaciones de palabras.
#     - además de cada palabra por separado, agregamos los grupo de N-palabras contiguas a nuestro vector de features.
#         - implementamos esto mediante: CountVectorizer(max_features=max_features, stop_words="english", ngram_range=(1,2))
#             - el argumento ngram_range señala el tamaño del vector (cuántas palabras combinadas con sentido quiero.
#             - el argumento max_features señala el número de palabras compuestas que tomará la función, en base a las palabras que más se repiten juntas (en base a ngram_range).
#
#
#
# ***
#
# `Term Frequecy (TF)`
#
# `- Frecuencia de una palabra (term) en una instancia o documento (doc).`
#
# - se calcula así: TF (term, doc)  # de veces que el term aparece en el doc/ # de terms diferentes en el doc.
#
# - Nos permite diferenciar documentos en base a las palabras que lo componen, sin tomar en cuenta las palabras que están en todos los documentos.
#
# - Para lograrlo, debemos medir no sólo cuánto aparece una palabra en una instancia(documento), sino también qué tan frecuente es esa palabra en todo el corpus.
#
# ***
#
# `Document Frequency (DF)`
#
# `- Fracción de todos los documentos que contienen el término en nuestro corpus.`
#
# - Se calcula así: # de docs que contienen term/ # total de docs
#
# ***
#
# `Inverse Term Frequency (ITF)`
#
# - Es el Logaritmo inversa de DF
#
# - Mientras más documentos tengan la misma palabra, menor será el IDF.
#
# - Se calcula así = LOG (# total de docs/# de docs que contienen term)
#
# ***
#
# `Inverse Document Frequency`
#
# `- Representa la relevancia del term en ese documento, tomando en cuenta los demás documentos.``
#
# - El IDF funciona como un ponderador, que señala que cuando ese término está siendo usado por otros documentos, entonces no lo toma en cuenta.
#
# - Producto del valor de TF por IDF.
#
# - eg aplicación: sistema de recomendación: raiting implícito.

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Carga de datos

# %%
import itertools

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import nltk

# Esto sirve para configurar NLTK. La primera vez puede tardar un poco
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/tomtom/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/tomtom/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
dataset = pd.read_json('Sarcasm_Headlines_Dataset.json', lines= True) #the line hyperparametr allow us t convert non structured to structured data
dataset.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %% [markdown]
# ¿Qué forma tiene el dataset?¿Cuántas instancias?¿Cuáles son sus columnas?¿Cuántos titulares hay de cada tipo?¿Podemos hablar ya de *features*?

# %%
dataset.shape
# Out:
# (26709, 3)

# %%
# see if the target variable is balanced or not
sns.countplot(dataset.is_sarcastic)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dataset[dataset.is_sarcastic==1].count()/dataset.shape[0]
# Out:
# article_link    0.438953
# headline        0.438953
# is_sarcastic    0.438953
# dtype: float64

# %%
dataset[dataset.is_sarcastic==0].count()/dataset.shape[0]
# Out:
# article_link    0.561047
# headline        0.561047
# is_sarcastic    0.561047
# dtype: float64

# %% [markdown]
# ## 2. Breve exploración del dataset
#
# Elige una instancia (texto) del dataset al azar y selecciona el *headline*.

# %%
index_random = np.random.randint(0,high = dataset.shape[0])
titular = dataset.iloc[index_random].headline
print("index ",index_random, ":", titular)
# Out:
# index  14590 : bill maher has superficial debate about 'n***a' after controversy

# %% [markdown]
# Sarcastic Identifier

# %%
if dataset.iloc[index_random].is_sarcastic==0:
    print("Not Sarcastic")
else:
    print("It is Sarcastic")
# Out:
# Not Sarcastic

# %% [markdown]
# ## 3. NLTK

# %% [markdown]
# 1. `sent_tokenize`

# %%
titular_st = nltk.tokenize.sent_tokenize(titular)
titular_st
# Out:
# ["bill maher has superficial debate about 'n***a' after controversy"]

# %% [markdown]
# 2. `word_tokenize`

# %%
titular_wt = nltk.tokenize.word_tokenize(titular)
titular_wt
# Out:
# ['bill',
#  'maher',
#  'has',
#  'superficial',
#  'debate',
#  'about',
#  "'",
#  'n',
#  '*',
#  '*',
#  '*',
#  'a',
#  "'",
#  'after',
#  'controversy']

# %% [markdown]
# ### Normalización

# %% [markdown]
# 1. Stopwords
#
# Importar los `stopwords` del inglés e imprimirlos.

# %%
stopwords = nltk.corpus.stopwords.words('english')
stopwords = [palabra for palabra in stopwords if 'not' not in palabra]
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %% [markdown]
# Eliminar los stopwords del texto.

# %%
titular_wt_sin_sw = [word for word in titular_wt if word not in stopwords]
titular_wt_sin_sw
# Out:
# ['bill',
#  'maher',
#  'superficial',
#  'debate',
#  "'",
#  'n',
#  '*',
#  '*',
#  '*',
#  "'",
#  'controversy']

# %% [markdown]
# ¿Cuál o cuáles palabras se fueron?

# %% [markdown]
# ### Frecuencia de palabras

# %%
freq = nltk.FreqDist(titular_wt_sin_sw)
freq
# Out:
# FreqDist({'*': 3, "'": 2, 'bill': 1, 'maher': 1, 'superficial': 1, 'debate': 1, 'n': 1, 'controversy': 1})

# %% [markdown]
# ### Análisis del Dataset Completo

# %%
filtrar = []
if True:
    filtrar.append("u")
    filtrar.append("new")

# %%
# I filter all the non sarcastic instances
dataset_no_sarcasmo = dataset[dataset.is_sarcastic==0]
dataset_no_sarcasmo.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
# 5  https://www.huffingtonpost.com/entry/advancing...
# 6  https://www.huffingtonpost.com/entry/how-meat-...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 4  j.k. rowling wishes snape happy birthday in th...             0
# 5                        advancing the world's women             0
# 6     the fascinating case for eating lab-grown meat             0

# %%
# create a list of lists with all the headlines tokenized

todos_titulares_no_sarcasmo = []
for i in range(dataset_no_sarcasmo.shape[0]):
    titular = dataset_no_sarcasmo.iloc[i].headline
    titular = nltk.tokenize.RegexpTokenizer("[\w]+").tokenize(titular)
    titular = [word for word in titular if word not in stopwords]
    titular = [word for word in titular if word not in filtrar]
    todos_titulares_no_sarcasmo.append(titular)
    
todos_titulares_no_sarcasmo
# Out:
# [['former',
#   'versace',
#   'store',
#   'clerk',
#   'sues',
#   'secret',
#   'black',
#   'code',
#   'minority',
#   'shoppers'],
#  ['roseanne',
#   'revival',
#   'catches',
#   'thorny',
#   'political',
#   'mood',
#   'better',
#   'worse'],
#  ['j',
#   'k',
#   'rowling',
#   'wishes',
#   'snape',
#   'happy',
#   'birthday',
#   'magical',
#   'way'],
#  ['advancing', 'world', 'women'],
#  ['fascinating', 'case', 'eating', 'lab', 'grown', 'meat'],
#  ['ceo', 'send', 'kids', 'school', 'work', 'company'],
#  ['friday', 'morning', 'email', 'inside', 'trump', 'presser', 'ages'],
#  ['airline',
#   'passengers',
#   'tackle',
#   'man',
#   'rushes',
#   'cockpit',
#   'bomb',
#   'threat'],
#  ['facebook', 'reportedly', 'working', 'healthcare', 'features', 'apps'],
#  ['north',
#   'korea',
#   'praises',
#   'trump',
#   'urges',
#   'us',
#   'voters',
#   'reject',
#   'dull',
#   'hillary'],
#  ['actually', 'cnn', 'jeffrey', 'lord', 'indefensible'],
#  ['barcelona', 'holds', 'huge', 'protest', 'support', 'refugees'],
#  ['bloomberg', 'program', 'build', 'better', 'cities', 'got', 'bigger'],
#  ['craig', 'hicks', 'indicted'],
#  ['qatar', 'deporting', 'dutch', 'woman', 'reported', 'drugged', 'raped'],
#  ['go', 'circus'],
#  ['ted',
#   'cruz',
#   'hits',
#   'panic',
#   'button',
#   'could',
#   'lose',
#   'houses',
#   'congress'],
#  ['writers', 'must', 'plan', 'surprised'],
#  ['obama', 'visits', 'arlington', 'national', 'cemetery', 'honor', 'veterans'],
#  ['remembrance', 'beginning', 'task'],
#  ['allies', 'islamist', 'motive', 'killing', 'nemtsov', 'nonsense'],
#  ['gillian', 'jacobs', 'like', 'kiss', 'adam', 'brody'],
#  ['uber',
#   'vows',
#   'repay',
#   'nyc',
#   'drivers',
#   'tens',
#   'millions',
#   'tax',
#   'snafu'],
#  ['apple', 'may', 'poached', 'electric', 'motorcycle', 'company', 'death'],
#  ['drug',
#   'resistant',
#   'bacteria',
#   'often',
#   'lurk',
#   'children',
#   'dogs',
#   'sandboxes'],
#  ['see', 'muslim', 'airport'],
#  ['moana',
#   'sails',
#   'straight',
#   'top',
#   'box',
#   'office',
#   'massive',
#   '81',
#   '1',
#   'million',
#   'opening'],
#  ['selig',
#   'counted',
#   'money',
#   'baseball',
#   'lost',
#   'next',
#   'generation',
#   'fans'],
#  ['devin',
#   'nunes',
#   'vows',
#   'never',
#   'reveal',
#   'source',
#   'surveillance',
#   'claims'],
#  ['scott',
#   'used',
#   'stop',
#   'breathing',
#   'nearly',
#   '40',
#   'times',
#   'hour',
#   'device',
#   'changed',
#   'life'],
#  ['medics', 'drop', 'soccer', 'player', 'stretcher', 'ticked'],
#  ['give', 'gift', 'play', 'holiday', 'season'],
#  ['spicer',
#   'denies',
#   'ending',
#   'maternity',
#   'care',
#   'guarantee',
#   'would',
#   'mean',
#   'women',
#   'pay',
#   'health',
#   'care'],
#  ['diy', 'sports', 'equipment', 'closet'],
#  ['1', 'dead', '3', 'injured', 'shooting', 'concert', 'nyc'],
#  ['donald', 'trump', 'heading', 'series', 'wins', 'northeast', 'polls', 'say'],
#  ['donald',
#   'trump',
#   'ready',
#   'cash',
#   'self',
#   'finance',
#   'entire',
#   'campaign',
#   'analysis'],
#  ['un',
#   'rights',
#   'chief',
#   'calls',
#   'humanitarian',
#   'situation',
#   'syria',
#   'outrage'],
#  ['track', 'santa', 'claus', 'flight', 'around', 'world', 'christmas', 'eve'],
#  ['one', 'planet', 'powerful', 'forces', 'change', 'adolescent', 'girl'],
#  ['draymond', 'green', 'take', 'game', 'next', 'level', 'tuning', 'wnba'],
#  ['ryan', 'lochte', 'apologizes', 'behavior', 'rio'],
#  ['4', 'lessons', 'prison', 'taught', 'power', 'control'],
#  ['america', 'first', 'muslim', 'fraternity', 'really', 'like'],
#  ['vicious',
#   'knot',
#   'syria',
#   'untangling',
#   'process',
#   'contains',
#   'solutions',
#   'time'],
#  ['congressman', 'thinks', 'fix', 'economy', 'drinking', 'beer'],
#  ['trump', 'orders', 'strikes', 'syria', 'retaliation', 'chemical', 'attack'],
#  ['year', 'round', 'schooling', 'would', 'help', 'minority', 'students'],
#  ['90', 'zen', 'teachers', 'pledge', 'change', 'culture', 'fosters', 'abuse'],
#  ['nypd',
#   'weighs',
#   'allowing',
#   'chokeholds',
#   'following',
#   'eric',
#   'garner',
#   'death'],
#  ['pope',
#   'francis',
#   'reminds',
#   'world',
#   'caring',
#   'earth',
#   'everyone',
#   'responsibility'],
#  ['gravity', '12', 'years', 'slave', 'tie', '2014', 'pga', 'awards'],
#  ['national',
#   'coming',
#   'day',
#   '150',
#   'lgbtq',
#   'sports',
#   'people',
#   'come',
#   'last',
#   'year'],
#  ['john',
#   'oliver',
#   'lays',
#   'disturbing',
#   'ways',
#   'trump',
#   'impacts',
#   'america'],
#  ['house', 'gop', 'crackdown', 'continues'],
#  ['look', 'world', 'cup', 'star', 'attacked', 'giant', 'bug'],
#  ['inhofe', 'grand', 'climate', 'conspiracy', 'theory', 'barbra', 'streisand'],
#  ['5', 'questions', 'wish', 'younger', 'people', 'would', 'stop', 'asking'],
#  ['albuquerque',
#   'shooter',
#   'loose',
#   'gunman',
#   'leaves',
#   '1',
#   'dead',
#   '3',
#   'injured'],
#  ['like', 'lose', 'everything', 'flood'],
#  ['demi', 'lovato', 'drops', 'emotional', 'nightingale', 'music', 'vid'],
#  ['miley', 'cyrus', 'liam', 'hemsworth', 'smooch', 'nye', 'world', 'notices'],
#  ['parks', 'rec', 'star', 'natalie', 'morales', 'comes', 'queer'],
#  ['top', 'italy', 'tours', '2015'],
#  ['kaia',
#   'gerber',
#   'cindy',
#   'crawford',
#   'daughter',
#   'lands',
#   'major',
#   'fashion',
#   'campaign'],
#  ['james',
#   'corden',
#   'roasts',
#   'david',
#   'beckham',
#   'matching',
#   'outfits',
#   'posh'],
#  ['mcdonald', 'says', 'packaging', '100', 'percent', 'green', '2025'],
#  ['kris', 'jenner', 'turned', 'way', 'drunken', 'valentine', 'day', 'karaoke'],
#  ['texas', 'ebola', 'patient', 'fighting', 'life'],
#  ['scott',
#   'pruitt',
#   'sort',
#   'answers',
#   'whether',
#   'trump',
#   'believes',
#   'climate',
#   'change'],
#  ['accused', 'father', 'son', 'urinal', 'thieves', 'flushed', 'cops'],
#  ['3',
#   'libertarians',
#   'fuel',
#   '7',
#   'million',
#   'super',
#   'pac',
#   'philadelphia',
#   'mayoral',
#   'democratic',
#   'primary'],
#  ['air', 'force', 'longer', 'require', 'help', 'god', 'enlistment', 'oaths'],
#  ['explosion',
#   'fells',
#   'building',
#   'outside',
#   'paris',
#   'killing',
#   'least',
#   '2'],
#  ['source', 'donald', 'trump', 'military', 'expertise', 'finally', 'revealed'],
#  ['union',
#   'claims',
#   'sanders',
#   'campaign',
#   'staffers',
#   'posed',
#   'members',
#   'influence',
#   'workers'],
#  ['seattle',
#   'mayor',
#   'accuser',
#   'sex',
#   'abuse',
#   'lawsuit',
#   'comes',
#   'forward'],
#  ['swedish',
#   'police',
#   'featured',
#   'film',
#   'shown',
#   'fox',
#   'news',
#   'say',
#   'selectively',
#   'edited'],
#  ['chromat', 'features', 'not', '1', '2', 'plus', 'size', 'models', 'runway'],
#  ['councilman', 'calls', 'baltimore', 'rappers', 'inspire', 'students'],
#  ['10', 'qualities', 'inner', 'spirit'],
#  ['parenting', 'advice', 'dare', 'give'],
#  ['celebrities', 'celebrate', 'fourth', 'july', 'fun', 'sun'],
#  ['international', 'women', 'day', 'western', 'women', 'save', 'world'],
#  ['michelle',
#   'phan',
#   'youtube',
#   'beauty',
#   'bestie',
#   'empowers',
#   'women',
#   'outside'],
#  ['caitlyn',
#   'jenner',
#   'responds',
#   'ricky',
#   'gervais',
#   'golden',
#   'globes',
#   'jokes'],
#  ['joy',
#   'behar',
#   'responds',
#   'michael',
#   'flynn',
#   'guilty',
#   'plea',
#   'pure',
#   'joy'],
#  ['6', 'things', 'one', 'tells', 'women', 'weight', 'loss', 'journey'],
#  ['ne',
#   'yo',
#   'helps',
#   'raise',
#   '2',
#   '3',
#   'million',
#   'california',
#   'engineering',
#   'school'],
#  ['elizabeth', 'warren', 'calls', 'donald', 'trump', 'racist', 'bully'],
#  ['six',
#   'dead',
#   '10',
#   'hurt',
#   'baltimore',
#   'commuter',
#   'school',
#   'bus',
#   'crash'],
#  ['kim', 'gordon', 'clarifies', 'comments', 'lana', 'del', 'rey', 'feminism'],
#  ['niece', 'cancer', 'ticked'],
#  ['supermodel',
#   'stephanie',
#   'seymour',
#   'arrested',
#   'charged',
#   'drunken',
#   'driving'],
#  ['scoliosis', 'need', 'know'],
#  ['controversy',
#   'erupts',
#   'uk',
#   'retailer',
#   'removes',
#   'gender',
#   'labels',
#   'kids',
#   'clothes'],
#  ['megyn',
#   'kelly',
#   'donald',
#   'trump',
#   'done',
#   'level',
#   'best',
#   'not',
#   'make',
#   'story'],
#  ['secret', 'behind', 'one', 'day', 'project', 'going', 'viral'],
#  ['creating', 'leverage', 'none', 'seems', 'exist'],
#  ['lawsuit',
#   'black',
#   'lives',
#   'matter',
#   'central',
#   'meaning',
#   'first',
#   'amendment'],
#  ['wire', 'cast', 'reunited', 'baltimore', 'uplift', 'community'],
#  ['obama',
#   'supreme',
#   'court',
#   'nominee',
#   'bragged',
#   'sending',
#   'man',
#   'prison',
#   'free'],
#  ['death', 'c', 'man', 'security', 'guard', 'custody', 'ruled', 'homicide'],
#  ['boehner', 'vows', 'leave', 'successor', 'clean', 'slate'],
#  ['facing', 'rising', 'seas', 'remote', 'alaskan', 'village', 'votes', 'move'],
#  ['worst', 'place', 'world', 'child'],
#  ['mom', 'sentenced', 'encouraging', 'boyfriend', 'sex', 'assault', 'baby'],
#  ['donald', 'trump', 'assault', 'values'],
#  ['women', 'march', 'inspired', 'run', 'unseating', 'gop', 'men'],
#  ['worth', 'america'],
#  ['gop', 'senators', 'ready', 'accept', 'trump', 'champion'],
#  ['price', 'gouging', 'pharma', 'ceo', 'takes', 'cancer', 'company'],
#  ['straight', 'outta', 'compton', 'stunning', 'surprise'],
#  ['carly', 'rae', 'jepsen', 'released', 'single'],
#  ['gunman',
#   'kills',
#   'one',
#   'wounds',
#   'four',
#   'shooting',
#   'german',
#   'nightclub'],
#  ['mountain',
#   'lion',
#   'tracked',
#   'scientists',
#   'found',
#   'dead',
#   'near',
#   'malibu',
#   'road'],
#  ['noah',
#   'cyrus',
#   'makes',
#   'late',
#   'night',
#   'debut',
#   'belting',
#   'make',
#   'cry'],
#  ['taylor', 'swift', 'used', 'gremlin', 'voice', 'writing', '1989'],
#  ['best', 'way', 'eat', 'avocados', 'avocado', 'pasta'],
#  ['open',
#   'letter',
#   'progressives',
#   'tpp',
#   'not',
#   'yet',
#   'progressive',
#   'trade',
#   'agreement',
#   'history'],
#  ['justice',
#   'thomas',
#   'wife',
#   'calls',
#   'supreme',
#   'court',
#   'retirement',
#   'report',
#   'bogus'],
#  ['7', 'ways', 'breakup', 'like', 'boss'],
#  ['sure',
#   'seems',
#   'like',
#   'frankie',
#   'muniz',
#   'wants',
#   'malcolm',
#   'middle',
#   'reboot'],
#  ['using', 'united', 'fiasco', 'flourish', 'future'],
#  ['thank',
#   'teacher',
#   'thursday',
#   'dominic',
#   'casulli',
#   'power',
#   'encouragement',
#   'part',
#   '1'],
#  ['toe',
#   'arctic',
#   'ocean',
#   'canada',
#   'northwest',
#   'territories',
#   'looney',
#   'front',
#   'part',
#   '2'],
#  ['never', 'happen'],
#  ['rubio', 'supporters', 'get', 'scuffle', 'rubiobot'],
#  ['music', 'strangers', 'film', 'review', 'dr', 'lloyd', 'sederer'],
#  ['obama',
#   'chides',
#   'darrell',
#   'issa',
#   'touting',
#   'alliance',
#   'election',
#   'fight'],
#  ['pope', 'francis', 'iraq', 'peace', 'message', 'meets', 'reality', 'war'],
#  ['ant',
#   'man',
#   'wasp',
#   'trailer',
#   'brings',
#   'fun',
#   'avengers',
#   'infinity',
#   'war'],
#  ['moses', 'red', 'sea'],
#  ['george', 'takei', 'accused', 'groping', 'former', 'male', 'model', '1981'],
#  ['hollywood',
#   'boys',
#   'club',
#   'supports',
#   'casey',
#   'affleck',
#   'total',
#   'disgrace'],
#  ['3', 'myths', 'low', 'libido'],
#  ['huffpollster',
#   'americans',
#   'see',
#   'progress',
#   'room',
#   'improvement',
#   'voting',
#   'rights'],
#  ['world', 'miss', 'goal', 'universal', 'education', '50', 'years', 'un'],
#  ['jennifer', 'lopez', 'name', 'jennifer', 'lopez'],
#  ['rebuild', 'credit', 'bankruptcy', 'fast'],
#  ['discover',
#   'climate',
#   'change',
#   'rapidly',
#   'transforming',
#   'earth',
#   'google',
#   'timelapse'],
#  ['voting', 'lines', 'shorter', 'mostly', 'whites'],
#  ['amanda', 'slavin', 'not', 'statistic'],
#  ['laurie',
#   'hernandez',
#   'val',
#   'chmerkovskiy',
#   'already',
#   'favorite',
#   'dancing',
#   'stars',
#   'couple'],
#  ['photos', 'show', 'hurricane', 'matthew', 'path', 'destruction', 'haiti'],
#  ['florida', 'lawmakers', 'vote', 'ban', 'marriage', 'age', '17'],
#  ['nick', 'viall', 'longer', 'bachelor'],
#  ['america', 'demonizes', 'teachers'],
#  ['fashion',
#   'designer',
#   'peter',
#   'som',
#   'legendary',
#   'minestrone',
#   'soup',
#   'recipe'],
#  ['photography',
#   'series',
#   'spotlighting',
#   'iconic',
#   'women',
#   '70',
#   'proves',
#   'best',
#   'yet',
#   'come'],
#  ['report', 'kenan', 'thompson', 'leaving', 'snl', 'deemed', 'inaccurate'],
#  ['woman', 'hid', 'heroin', 'oxy', 'fake', 'butt', 'cops', 'say'],
#  ['cry'],
#  ['isis', 'g', '41', 'world'],
#  ['sarah',
#   'huckabee',
#   'sanders',
#   'defends',
#   'trump',
#   'sexist',
#   'attack',
#   'kirsten',
#   'gillibrand'],
#  ['saying', 'goodbye', 'hollywood', 'hottest', 'seediest', 'address'],
#  ['11',
#   'years',
#   'later',
#   'human',
#   'genome',
#   'paves',
#   'way',
#   'genomic',
#   'technonlogy'],
#  ['man', 'claiming', 'boko', 'haram', 'leader', 'appears', 'video'],
#  ['live', 'knowing', 'proof', 'heaven'],
#  ['pilgrimage', 'india'],
#  ['religious', 'freedom', 'advocates', 'oppose', 'roy', 'moore'],
#  ['uaw',
#   'fca',
#   'still',
#   'negotiating',
#   'hour',
#   'hour',
#   'contract',
#   'extension'],
#  ['bernie',
#   'sanders',
#   'wanted',
#   'solve',
#   'problems',
#   'like',
#   'donald',
#   'trump'],
#  ['right', 'way', 'write'],
#  ['north',
#   'carolina',
#   'seem',
#   'want',
#   'people',
#   'see',
#   'police',
#   'camera',
#   'footage'],
#  ['education',
#   'department',
#   'officially',
#   'deal',
#   'transgender',
#   'students',
#   'experiencing',
#   'bathroom',
#   'discrimination'],
#  ['participating', 'black', 'friday'],
#  ['merkel', 'isis', 'poses', 'major', 'risk', 'europe'],
#  ['devastating', 'floods', 'leave', '23', 'dead', 'west', 'virginia'],
#  ['obama', 'greatest', 'oratory', 'performance'],
#  ['6', 'summer', 'salads', 'actually', 'crave'],
#  ['black', 'keys', 'album', 'turn', 'blue', 'available', 'stream', 'full'],
#  ['isis', 'vs', 'isil', 'name'],
#  ['tomi', 'lahren', 'suing', 'glenn', 'beck', 'theblaze'],
#  ['greg',
#   'hardy',
#   'unapologetically',
#   'denies',
#   'domestic',
#   'abuse',
#   'allegations'],
#  ['tourists', 'describe', 'scenes', 'horror', 'tunisian', 'beach', 'massacre'],
#  ['trump', 'voters', 'blink'],
#  ['photos',
#   'ahs',
#   'set',
#   'may',
#   'help',
#   'explain',
#   'creepy',
#   'blond',
#   'children'],
#  ['psychologists', 'push', 'smartphone', 'warning', 'labels'],
#  ['republican', 'obamacare', 'dilemma', 'one', '6', 'minute', 'video'],
#  ['mass', 'graves', 'suggest', 'systematic', 'killing', 'rohingya', 'myanmar'],
#  ['private',
#   'prison',
#   'companies',
#   'still',
#   'lock',
#   'immigrants',
#   'despite',
#   'doj',
#   'decision'],
#  ['grateful',
#   'dead',
#   'lyricist',
#   'internet',
#   'pioneer',
#   'john',
#   'perry',
#   'barlow',
#   'dead',
#   '70'],
#  ['philippines', 'president', 'calls', 'civilians', 'kill', 'drug', 'addicts'],
#  ['woman', 'perfectly', 'breaks', 'not', 'nurse'],
#  ['amid', 'chattering', 'global', 'elite', 'silent', 'interlude'],
#  ['least',
#   '23',
#   'ethical',
#   'issues',
#   'dogging',
#   'epa',
#   'administrator',
#   'scott',
#   'pruitt'],
#  ['ask', 'tell'],
#  ['vegas', 'baby', 'well', 'minus', 'babies'],
#  ['people',
#   'really',
#   'like',
#   'kanye',
#   'song',
#   'real',
#   'friends',
#   'really',
#   'g'],
#  ['20', 'suede', 'pieces', 'want', 'wear', 'spring'],
#  ['behold', 'title', 'american', 'horror', 'story', 'season', '7'],
#  ['football',
#   'loving',
#   'americans',
#   'harassed',
#   'wearing',
#   'turbans',
#   'nfl',
#   'game'],
#  ['health'],
#  ['seth', 'meyers', 'loses', 'thanksgiving', 'proximity', 'christmas'],
#  ['15', 'ways', 'knicks', 'trade', 'carmelo', 'anthony'],
#  ['parents', 'fight', 'save', 'two', 'daughters', 'tragic', 'diagnosis'],
#  ['quiet', 'practice', 'found', 'voice'],
#  ['everyone',
#   'told',
#   'second',
#   'child',
#   'would',
#   'much',
#   'harder',
#   'first',
#   'wrong'],
#  ['man',
#   'reportedly',
#   'unleashes',
#   'trump',
#   'inspired',
#   'anti',
#   'lgbtq',
#   'rant',
#   'church'],
#  ['finding', 'voice', 'wendy', 'davis'],
#  ['trump', 'rage', 'campaign', 'opened', 'door', 'james', 'comey', 'firing'],
#  ['looking', 'happiness', 'wrong', 'places'],
#  ['swarm',
#   '100',
#   'drones',
#   'dance',
#   'beethoven',
#   'symphony',
#   '5',
#   'night',
#   'sky'],
#  ['outfit', 'got', 'woman', 'kicked', 'school', 'gym'],
#  ['saturday',
#   'night',
#   'live',
#   'celebrates',
#   'halloween',
#   'spooktacular',
#   'montage'],
#  ['disaster',
#   'movies',
#   'tame',
#   'compared',
#   'happened',
#   '3',
#   '3',
#   'billion',
#   'years',
#   'ago'],
#  ['washington', 'c', 'officer', 'shoots', 'woman', 'carrying', 'knife'],
#  ['face', 'hidden', 'history', 'plastic', 'surgery', 'looks', 'matter'],
#  ['knicks', 'fan', 'open', 'letter', 'santa'],
#  ['donald', 'trump', 'america', 'blood', 'sport', 'choice'],
#  ['time', 'end', 'subsidies', 'destroying', 'forests'],
#  ['netflix', 'shut', 'planned', 'louis', 'c', 'k', 'comedy', 'special'],
#  ['trump',
#   'undercuts',
#   'easy',
#   'obamacare',
#   'attack',
#   'dig',
#   'bill',
#   'clinton',
#   'infidelities'],
#  ['got', 'exclusive', 'look', 'hillary', 'dnc', 'speech', 'notes'],
#  ['watch',
#   'john',
#   'kasich',
#   'lead',
#   'awkward',
#   'david',
#   'bowie',
#   'sing',
#   'along'],
#  ['social', 'media', 'detox', 'helped', 'ed', 'burns', 'become', 'productive'],
#  ['north', 'korea', 'claims', 'planning', 'fire', 'missiles', 'near', 'guam'],
#  ['make', '4', 'month', 'old', 'fall', 'love', 'reading'],
#  ['15', 'weirdest', 'things', 'people', 'left', 'behind', 'uber'],
#  ['arkansas', 'executes', 'first', 'inmate', '12', 'years'],
#  ['sadder', 'pride', 'washington', 'inaction'],
#  ['shonda', 'rhimes', 'motivation', 'behind', 'weight', 'loss', 'journey'],
#  ['obama', 'plans', 'tackle', 'major', 'education', 'inequality'],
#  ['teaching', 'learning', 'college', 'ratings', 'framework'],
#  ['fashion',
#   'forward',
#   'pigeon',
#   'sports',
#   'bread',
#   'necklace',
#   'bold',
#   'style',
#   'choice'],
#  ['video',
#   'relaunches',
#   'investigation',
#   'death',
#   'man',
#   'held',
#   'chicago',
#   'police'],
#  ['whoopi', 'goldberg', 'says', 'oscars', 'racist'],
#  ['sherman',
#   'alexie',
#   'says',
#   'artists',
#   'trump',
#   'noise',
#   'canceling',
#   'headphones'],
#  ['nbc', 'news', 'correspondent', 'ayman', 'mohyeldin', 'returning', 'gaza'],
#  ['sen',
#   'tom',
#   'cotton',
#   'thinks',
#   'tough',
#   'guy',
#   'trump',
#   'ready',
#   'resume',
#   'waterboarding'],
#  ['mike', 'ditka', 'not', 'paying', 'attention', 'history'],
#  ['ivanka',
#   'trump',
#   'incorrectly',
#   'names',
#   'judaism',
#   '1',
#   '3',
#   'largest',
#   'world',
#   'religions'],
#  ['rescued', 'lion', 'obsessed', 'blankets', 'since', 'baby'],
#  ['best', 'toys', 'shop', 'prime', 'day', 'kids', 'ages'],
#  ['sanders', 'phenomenon'],
#  ['khloe', 'kardashian', 'joins', 'waist', 'gang'],
#  ['next', 'week', 'republican', 'debate', 'utah', 'canceled'],
#  ['trove',
#   'lost',
#   'found',
#   'photos',
#   'reveal',
#   'one',
#   'mystery',
#   'couple',
#   'beautiful',
#   'life'],
#  ['bear', 'family', 'pool', 'party', 'cutest', 'backyard', 'invasion', 'ever'],
#  ['dustin',
#   'hoffman',
#   'accusers',
#   'speak',
#   'alleged',
#   'abuse',
#   'joint',
#   'nbc',
#   'interview'],
#  ['another',
#   'open',
#   'letter',
#   'betsy',
#   'devos',
#   'public',
#   'school',
#   'teacher'],
#  ['6', 'tips', 'boost', 'career'],
#  ['video',
#   'shows',
#   'transphobic',
#   'man',
#   'preaching',
#   'target',
#   'getting',
#   'shut',
#   'customer'],
#  ['xmasgiftsfromtrump',
#   'wish',
#   'list',
#   'give',
#   'trump',
#   'un',
#   'merry',
#   'christmas'],
#  ['ronda', 'rousey', 'eerily', 'predicted', 'would', 'lose'],
#  ['brief', 'pun', 'intended', 'history', 'lawyers', 'movies'],
#  ['gifs',
#   'memphis',
#   'grizzlies',
#   'weathered',
#   'epic',
#   'oklahoma',
#   'city',
#   'thunder',
#   'storm'],
#  ['russia', 'denies', 'compromising', 'information', 'donald', 'trump'],
#  ['comics', 'offer', 'bible', 'readers'],
#  ['breaking', 'uniform'],
#  ['7', 'fascinating', 'forgotten', 'facts', 'world', 'war', 'book'],
#  ['key', 'setting', 'achievable', 'goals'],
#  ['shopping', 'guide', 'cyber', 'monday', 'need'],
#  ['donald',
#   'trump',
#   'says',
#   'refugee',
#   'crisis',
#   'threats',
#   'uk',
#   'identity',
#   'drove',
#   'brexit'],
#  ['gunman',
#   'kills',
#   'least',
#   'two',
#   'american',
#   'advisers',
#   'kabul',
#   'shooting'],
#  ['kris',
#   'kobach',
#   'defends',
#   'using',
#   'private',
#   'email',
#   'government',
#   'business'],
#  ['charles', 'darwin', 'sunmine'],
#  ['another', 'way', 'companies', 'make', 'harder', 'mothers'],
#  ['want', 'make', 'meetings', 'productive', 'start', 'walking'],
#  ['watch', 'stone', 'brewing', 'evacuates', 'wildfire', 'approaches'],
#  ['military',
#   'prosecutor',
#   'senate',
#   'report',
#   'cia',
#   'interrogation',
#   'program',
#   'accurate'],
#  ['national',
#   'park',
#   'service',
#   'studies',
#   'historic',
#   'lgbtq',
#   'sites',
#   'possible',
#   'recognition'],
#  ['safeguarding', 'america', 'health', 'system', 'sabotage'],
#  ['skydiver', 'luke', 'aikins', 'makes', 'jump', 'without', 'parachute'],
#  ['senate', 'republicans', 'kowtow', 'trump', 'far', 'right'],
#  ['viral',
#   'photo',
#   'captures',
#   'incredible',
#   'moment',
#   'police',
#   'officer',
#   'homeless',
#   'man'],
#  ['inside', 'story', 'congress', 'sent', 'stock', 'market', 'tumbling'],
#  ['different', 'kind', 'mom'],
#  ['uber',
#   'halts',
#   'self',
#   'driving',
#   'car',
#   'tests',
#   'california',
#   'test',
#   'much',
#   'anyway'],
#  ['tiger',
#   'mothers',
#   'fresh',
#   'boat',
#   'eddie',
#   'huang',
#   'mom',
#   'not',
#   'every',
#   'asian',
#   'american',
#   'mom'],
#  ['donald', 'trump', 'thinks', 'roger', 'goodell', 'weak', 'stupid', 'dope'],
#  ['trump',
#   'says',
#   'congress',
#   'change',
#   'libel',
#   'laws',
#   'decision',
#   'states'],
#  ['shirtless',
#   'goofball',
#   'flag',
#   'underwear',
#   'invades',
#   'field',
#   'world',
#   'series'],
#  ['chinese', 'parents', 'say', 'love'],
#  ['americans', 'say', 'white', 'house', 'creating', 'problems', 'solves'],
#  ['lancet', 'breakthrough', 'publishing', 'faith', 'health'],
#  ['criticism',
#   'cleveland',
#   'officials',
#   'outline',
#   'convention',
#   'security',
#   'plans'],
#  ['justin',
#   'bieber',
#   'interrupts',
#   'performance',
#   'scold',
#   'spanish',
#   'audience'],
#  ['mudbound', 'oscar', 'nominations', 'place', 'netflix', 'big', 'leagues'],
#  ['kendrick',
#   'lamar',
#   'taylor',
#   'swift',
#   'weeknd',
#   'lead',
#   '2016',
#   'grammy',
#   'nominations'],
#  ['nbc',
#   'dramatize',
#   'menendez',
#   'brothers',
#   'murders',
#   'law',
#   'order',
#   'true',
#   'crime',
#   'spinoff'],
#  ['police',
#   'assume',
#   'truck',
#   'deliberately',
#   'driven',
#   'berlin',
#   'christmas',
#   'market'],
#  ['shooting', 'orlando', 'chefs', 'provide', 'thousands', 'free', 'meals'],
#  ['gop',
#   'sen',
#   'jeff',
#   'flake',
#   'comes',
#   'says',
#   'party',
#   'might',
#   'not',
#   'deserve',
#   'lead'],
#  ['dentist', 'offers', 'buy', 'back', 'halloween', 'candy'],
#  ['restaurant',
#   'teaches',
#   'former',
#   'inmates',
#   'cook',
#   'helps',
#   'get',
#   'back',
#   'feet'],
#  ['5', 'entrepreneurial', 'rules', 'live'],
#  ['7', 'things', 'probably', 'know', 'christmas'],
#  ['paul',
#   'beatty',
#   'becomes',
#   'first',
#   'american',
#   'win',
#   'man',
#   'booker',
#   'prize',
#   'fiction'],
#  ['favorite', 'female', 'star', 'wars', 'heroes', 'finally', 'get', 'series'],
#  ['ted', 'cruz', 'super', 'pacs', 'take', 'record', 'haul'],
#  ['domestic',
#   'abuse',
#   'survivor',
#   'gives',
#   'young',
#   'victims',
#   'support',
#   'wishes'],
#  ['dogs', 'smell', 'grandma', 'scent', 'set', 'quest', 'find'],
#  ['smb', 'changing', 'way', 'business'],
#  ['really', 'listen', 'difficult', 'conversation', '6', '2'],
#  ['really', 'like', 'miscarriage'],
#  ['businesses',
#   'say',
#   'anti',
#   'lgbt',
#   'bills',
#   'could',
#   'cost',
#   'texas',
#   'billions'],
#  ['accused', 'killer', 'wanted', 'army', 'people', 'anything', 'asked'],
#  ['british', 'public', 'hunt', 'witches', 'marks', 'halloween'],
#  ['best', 'volunteer', 'programs'],
#  ['michael',
#   'b',
#   'jordan',
#   'sets',
#   'fire',
#   'first',
#   'fahrenheit',
#   '451',
#   'trailer'],
#  ['social',
#   'unity',
#   'important',
#   'says',
#   'pm',
#   'modi',
#   'india',
#   '70th',
#   'independence',
#   'day'],
#  ['roe', 'made', 'abortions', 'legal', 'keep', 'women', 'providers', 'safe'],
#  ['dreamers', 'face', 'nightmare', 'trump', 'deportation', 'force'],
#  ['whoops',
#   'selfie',
#   'snapper',
#   'smashes',
#   'sculpture',
#   'days',
#   'exhibit',
#   'opens'],
#  ['9', 'things', 'parents', 'college', 'kids', 'hate', 'admit'],
#  ['watch',
#   'underreported',
#   'story',
#   'reuniting',
#   'families',
#   'remains',
#   'dead',
#   'migrants'],
#  ['yahoo', 'newfront', 'pulses', 'steve', 'aoki', 'edm', 'beat'],
#  ['lose',
#   'islamic',
#   'state',
#   'obama',
#   'administration',
#   'considers',
#   'deploying',
#   'troops',
#   'iraq',
#   'focusing',
#   'assad',
#   'syria'],
#  ['eric',
#   'bogosian',
#   'operation',
#   'nemesis',
#   'genocide',
#   'ever',
#   'truly',
#   'avenged'],
#  ['thousands', 'protest', 'moscow', 'housing', 'plan'],
#  ['tattoo',
#   'shop',
#   'creating',
#   'safe',
#   'accepting',
#   'space',
#   'queer',
#   'bodies'],
#  ['author',
#   'jeff',
#   'lindsay',
#   'says',
#   'goodbye',
#   'serial',
#   'killer',
#   'dexter',
#   'final',
#   'novel'],
#  ['koch', 'network', 'spent', 'nearly', '400', 'million', '2015'],
#  ['nooses', 'university', 'delaware'],
#  ['30', 'unbeleafably', 'adorable', 'gifts', 'plant', 'lovers'],
#  ['cuomo', 'makes', 'surprise', 'afghanistan', 'trip'],
#  ['nobody',
#   'watched',
#   'matthew',
#   'mcconaughey',
#   'forgotten',
#   'youtube',
#   'channel'],
#  ['becoming', 'parent', 'done'],
#  ['video', 'icantbreathe', 'poem', 'house', 'floor'],
#  ['donald', 'w', 'bush'],
#  ['congressman',
#   'calls',
#   'trump',
#   'idiot',
#   'using',
#   'egypt',
#   'mosque',
#   'attack',
#   'promote',
#   'border',
#   'wall'],
#  ['luke',
#   'bryan',
#   'says',
#   'confederate',
#   'flag',
#   'become',
#   'symbol',
#   'racism'],
#  ['germans'],
#  ['kentucky',
#   'governor',
#   'echoes',
#   'trump',
#   'sides',
#   'blame',
#   'charlottesville',
#   'violence'],
#  ['caitlyn', 'jenner', 'helping', 'better'],
#  ['wild', 'tales', 'outstanding', 'black', 'comedy', 'cannes'],
#  ['donald',
#   'trump',
#   'prefers',
#   'violent',
#   'football',
#   'black',
#   'players',
#   'get',
#   'hurt',
#   'espn',
#   'analyst'],
#  ['black', 'ribbon', 'balsam'],
#  ['buttermilk', 'biscuit', 'recipes', 'want', 'need'],
#  ['ai',
#   'weiwei',
#   'commemorates',
#   'drowned',
#   'refugees',
#   'berlin',
#   'film',
#   'festival'],
#  ['restrictions',
#   'journalists',
#   'agreed',
#   'order',
#   'attend',
#   'koch',
#   'brothers',
#   'conference'],
#  ['little', 'boy', 'stands', 'tall'],
#  ['jake',
#   'tapper',
#   'one',
#   'word',
#   'response',
#   'creepy',
#   'kellyanne',
#   'conway',
#   'snl',
#   'sketch'],
#  ['poll',
#   'shows',
#   'support',
#   'birth',
#   'control',
#   'mandate',
#   'eve',
#   'court',
#   'ruling'],
#  ['death', 'row', 'inmate', 'loses', 'fight', 'kosher', 'food'],
#  ['jada',
#   'pinkett',
#   'smith',
#   'gabrielle',
#   'union',
#   'end',
#   'feud',
#   '17',
#   'years'],
#  ['huffpost', 'rise', 'need', 'know', 'february', '10'],
#  ['dear', 'mr', 'president', 'dispatch', 'bowling', 'green'],
#  ['shinto',
#   'priestess',
#   'killed',
#   'brother',
#   'sword',
#   'attack',
#   'tokyo',
#   'shrine'],
#  ['journalists',
#   'push',
#   'back',
#   'correspondents',
#   'association',
#   'response',
#   'michelle',
#   'wolf'],
#  ['nina', 'dobrev', 'addresses', 'rumored', 'return', 'vampire', 'diaries'],
#  ['theresa',
#   'may',
#   'edging',
#   'towards',
#   'donald',
#   'trump',
#   'scolds',
#   'john',
#   'kerry',
#   'israel'],
#  ['year',
#   'eve',
#   'prank',
#   'leaves',
#   '4',
#   'year',
#   'old',
#   'glued',
#   'mcdonald',
#   'toilet'],
#  ['prosecutors',
#   'tamir',
#   'rice',
#   'case',
#   'bizarrely',
#   'pointed',
#   'toy',
#   'gun',
#   'witness',
#   'lawyers',
#   'allege'],
#  ['wrong', 'picture', 'fight', 'isis', 'everything'],
#  ['afi', 'docs', 'policy', 'meets', 'art'],
#  ['real', 'mothers', 'mother', 'day'],
#  ['dad', 'shoots', 'daughter', 'teaching', 'gun', 'safety'],
#  ['3', 'unexpected', 'ways', 'help', 'kids', 'mindful', 'screen', 'time'],
#  ['dee', 'bogetti', 'gps', 'guide', 'living', 'moment'],
#  ['starving', 'fantasy'],
#  ['volkswagen', 'recalled'],
#  ['read', 'not', 'read', 'part', '2'],
#  ['hillary', 'clinton', 'loses', 'lead', 'bernie', 'sanders', 'iowa', 'poll'],
#  ['several',
#   'women',
#   'accuse',
#   'progressive',
#   'media',
#   'executive',
#   'hazen',
#   'sexual',
#   'harassment'],
#  ['success', 'still', 'enjoying', 'happy', 'place'],
#  ['lin',
#   'manuel',
#   'miranda',
#   'freestyles',
#   'life',
#   'annoying',
#   'minor',
#   'inconveniences',
#   'ellen'],
#  ['john',
#   'lewis',
#   'attend',
#   'civil',
#   'rights',
#   'museum',
#   'opening',
#   'trump',
#   'going'],
#  ['trouble', 'brewing', '2015', 'npt', 'review', 'conference'],
#  ['huffpost',
#   'hill',
#   'secret',
#   'service',
#   'agents',
#   'really',
#   'glad',
#   'dark',
#   'sunglasses',
#   'hide',
#   'bloodshot',
#   'eyes'],
#  ['photograph', 'remember'],
#  ['bobsled',
#   'team',
#   'pays',
#   'tribute',
#   'late',
#   'gold',
#   'medalist',
#   'steven',
#   'holcomb'],
#  ['among',
#   'santa',
#   'fe',
#   'many',
#   'virtues',
#   'history',
#   'art',
#   'culture',
#   'hospitality',
#   'killer',
#   'vintage',
#   'clothing'],
#  ['power', 'plan', 'foes', 'mars', 'backers', 'venus', 'earth', 'actually'],
#  ['journalists', 'refuse', 'take', 'non', 'answer', 'answer'],
#  ['nukes', 'global', 'schism'],
#  ['negro', 'week', '1939', '1940', 'york', 'world', 'fair'],
#  ['trump',
#   'threatens',
#   'veto',
#   'spending',
#   'bill',
#   'border',
#   'wall',
#   'funding',
#   'signs'],
#  ['6', 'diy', 'stress', 'hacks', 'using', 'closet'],
#  ['major', 'concern', 'phone', 'call', 'taiwan'],
#  ['weird',
#   'wonderful',
#   'cabaret',
#   'chronicle',
#   'karen',
#   'mason',
#   'revisits',
#   'roots',
#   'tell',
#   'mama'],
#  ['companies', 'hide', 'financial', 'risks', 'climate', 'change'],
#  ['louvre', 'gardens', 'teeming', 'rats'],
#  ['trump', '1', 'polls', 'macarena'],
#  ['boy', 'george', 'opens', 'happiness', 'politics', 'junkie'],
#  ['patrick',
#   'stewart',
#   'reads',
#   'hilariously',
#   'bad',
#   'reviews',
#   'iconic',
#   'tourist',
#   'attractions'],
#  ['safeguarding', 'well', 'children'],
#  ['public', 'health', 'threat', 'private', 'anger'],
#  ['friendly',
#   'wildly',
#   'hot',
#   'reminder',
#   'oscar',
#   'isaac',
#   'playing',
#   'hamlet'],
#  ['hbo',
#   'documentary',
#   'shows',
#   'really',
#   'like',
#   'inside',
#   'terror',
#   'attack'],
#  ['watch', 'stories', 'believe', 'world', 'dirtiest', 'jobs'],
#  ['golf',
#   'sensation',
#   'jordan',
#   'spieth',
#   'loses',
#   'masters',
#   'horrible',
#   'meltdown',
#   'danny',
#   'willett',
#   'wins'],
#  ['first',
#   'gay',
#   'couple',
#   'receives',
#   'marriage',
#   'license',
#   'jailed',
#   'kentucky',
#   'clerk',
#   'office'],
#  ['john', 'mccain', 'czar', 'hater', 'calls', 'ebola', 'czar'],
#  ['father', 'trump', 'tower', 'climber', 'also', 'important', 'message'],
#  ['sanders', 'hits', 'bill', 'clinton', 'welfare', 'reform', 'trade'],
#  ['white',
#   'nationalist',
#   'calls',
#   'trump',
#   'denouncement',
#   'hate',
#   'groups',
#   'kumbaya',
#   'nonsense'],
#  ['details', 'paint', 'unsettling', 'pictures', 'london', 'attackers'],
#  ['ask', 'get', 'history', 'breast', 'cancer'],
#  ['facebook', 'wallflower', 'good', 'social', 'site', 'says'],
#  ['valentine', 'best', 'friend', 'life', 'without'],
#  ['importance', 'collaborative'],
#  ['adele',
#   'tweets',
#   'apology',
#   'stage',
#   'rigging',
#   'hits',
#   'glasgow',
#   'concertgoer'],
#  ['religious',
#   'freedom',
#   'clauses',
#   'point',
#   'contention',
#   'australia',
#   'crafts',
#   'marriage',
#   'equality',
#   'laws'],
#  ['voters',
#   'excited',
#   'november',
#   'despite',
#   'not',
#   'really',
#   'loving',
#   'likely',
#   'nominees'],
#  ['internet',
#   'personality',
#   'michael',
#   'buckley',
#   'giving',
#   'sex',
#   'tips',
#   'broadway'],
#  ['legends', 'york', 'latex', 'ball', 'celebrate', 'history', 'voguing'],
#  ['trump', 'telling', 'jokes', 'nobody', 'laughing'],
#  ['kellie',
#   'pickler',
#   'hilariously',
#   'misses',
#   'buzzer',
#   'celebrity',
#   'family',
#   'feud',
#   'fail'],
#  ['jeb', 'bush', 'insists', 'washington', 'outsider'],
#  ['washington',
#   'post',
#   'journalist',
#   'jailed',
#   'iran',
#   'christmas',
#   'meal',
#   'family'],
#  ['coloradans',
#   'deregistered',
#   'trump',
#   'request',
#   'voter',
#   'data',
#   'signing'],
#  ['watch', 'vin', 'diesel', 'say', 'groot', 'different', 'languages'],
#  ['artist',
#   'stunning',
#   'image',
#   'honors',
#   'moment',
#   'one',
#   'woman',
#   'defied',
#   'neo',
#   'nazi',
#   'march'],
#  ['year', 'resolution', 'let', 'colleges', 'lead', 'way', 'normal', 'cuba'],
#  ['paris',
#   'police',
#   'arrest',
#   'second',
#   'couple',
#   'notre',
#   'dame',
#   'gas',
#   'cylinders'],
#  ['8', 'favorite', 'beauty', 'products'],
#  ['financial', 'burden', 'cancer', 'harm', 'quality', 'life'],
#  ['quadruple', 'bottom', 'line', 'time', 'come'],
#  ['may', 'holding', 'back', 'repairing', 'broken', 'relationship'],
#  ['weeks',
#   'trump',
#   'takes',
#   'office',
#   'obama',
#   'mad',
#   'dash',
#   'save',
#   'public',
#   'lands'],
#  ['changing', 'holiday', 'shopping', 'landscape'],
#  ['road', 'sign', 'lot', 'less', 'helpful', 'looks'],
#  ['australian',
#   'lawmaker',
#   'shoots',
#   'opponents',
#   'campaign',
#   'ad',
#   'draws',
#   'ire',
#   'orlando'],
#  ['kinda', 'creepy', 'peter', 'pan', 'pranks', 'disney', 'world'],
#  ['brownribboncampaign',
#   'reminds',
#   'us',
#   'oscar',
#   'diversity',
#   'black',
#   'white'],
#  ['america', 'future', 'engineering', 'needs', 'diversify'],
#  ['darrelle',
#   'revis',
#   'charged',
#   'fight',
#   'leaves',
#   'two',
#   'men',
#   'unconscious'],
#  ['pay', 'another', 'bill', 'pay'],
#  ['blm',
#   'alicia',
#   'garza',
#   'launches',
#   'census',
#   'project',
#   'mobilize',
#   'black',
#   'political',
#   'power'],
#  ['police',
#   'audio',
#   'leaked',
#   'killing',
#   'unarmed',
#   'black',
#   'teen',
#   'christian',
#   'taylor'],
#  ['first', 'time', 'marathoner', 'strength', 'numbers'],
#  ['hate',
#   'preachers',
#   'qatar',
#   'campus',
#   'obama',
#   'gives',
#   'qatar',
#   'undeserved',
#   'fighting',
#   'incitement'],
#  ['3', 'reminders', 'help', 'raise', 'resilient', 'kids'],
#  ['shooting',
#   'copenhagen',
#   'synagogue',
#   'leaves',
#   '1',
#   'dead',
#   '2',
#   'officers',
#   'wounded'],
#  ['paris',
#   'hilton',
#   'impersonates',
#   'kim',
#   'kardashian',
#   'kanye',
#   'west',
#   'fashion',
#   'line'],
#  ['teen', 'accepted', '113', 'colleges', 'chooses', 'full', 'ride', 'hbcu'],
#  ['transgender',
#   'lawmaker',
#   'danica',
#   'roem',
#   'trump',
#   'shows',
#   'barrier',
#   'getting',
#   'elected'],
#  ['7th', 'heaven', 'cast', 'reunites', 'first', 'time', '8', 'years'],
#  ['nothing', 'libertarian', 'conservatives'],
#  ['introvert', 'guide', 'throwing', 'solid', 'holiday', 'party'],
#  ['fifth',
#   'harmony',
#   'lauren',
#   'jauregui',
#   'blasts',
#   'toxic',
#   'homophobia',
#   'poignant',
#   'twitter',
#   'exchange'],
#  ['six',
#   'teenagers',
#   'britain',
#   'suspected',
#   'killing',
#   'polish',
#   'man',
#   'hate',
#   'crime'],
#  ['bill', 'henderson', 'jazz', 'vocalist', 'actor', 'dies', '90'],
#  ['emotionally', 'recover', 'election'],
#  ['6', 'essentials', 'trash', 'free', 'lunch'],
#  ['schools', 'enact', 'positive', 'change', 'drama', 'therapy'],
#  ['professor',
#   'threatened',
#   'firing',
#   'says',
#   'wheaton',
#   'college',
#   'changing',
#   'rules'],
#  ['late',
#   'show',
#   'updated',
#   'trump',
#   'election',
#   'night',
#   'speech',
#   'annotations'],
#  ['ancient', 'flying', 'beast', 'named', 'avatar', 'creature'],
#  ['tennessee',
#   'senate',
#   'passes',
#   'bill',
#   'erect',
#   'memorial',
#   'victims',
#   'abortion'],
#  ['stakes', 'high', 'bother', 'white', 'tears'],
#  ['growing', 'holocaust', 'writer'],
#  ['surprising', 'way', 'horses', 'help', 'ease', 'alzheimer', 'symptoms'],
#  ['huffpollster', 'republican', 'women', 'really', 'like', 'trump'],
#  ['know', 'far', 'white', 'house', 'org', 'chart'],
#  ['5', 'longevity', 'secrets', 'world', 'healthiest', 'cultures'],
#  ['8', 'perks', 'divorced', 'holidays'],
#  ['moms', 'demand', 'action', 'participate', 'day', 'without', 'woman'],
#  ['hillary',
#   'clinton',
#   'asian',
#   'american',
#   'outreach',
#   'director',
#   'leaving',
#   'campaign'],
#  ['interview', 'louise', 'munson', 'playwright', 'luigi'],
#  ['suspect',
#   'reportedly',
#   'arrested',
#   'explosives',
#   'sent',
#   'washington',
#   'c',
#   'area'],
#  ['writer',
#   'calls',
#   'women',
#   'color',
#   'divest',
#   'lena',
#   'dunham',
#   'controversy'],
#  ['unexpected', 'place', 'probably', 'overeating'],
#  ['lemon', 'sean', 'spicer', 'everyone', 'dumber', 'listened'],
#  ['kansas',
#   'state',
#   'refused',
#   'investigate',
#   'sexual',
#   'assaults',
#   'happened',
#   'campus',
#   'lawsuit',
#   'says'],
#  ['nfl',
#   'player',
#   'avery',
#   'williamson',
#   'wears',
#   '9',
#   '11',
#   'cleats',
#   'despite',
#   'threat',
#   'fine'],
#  ['trump',
#   'confidant',
#   'floats',
#   'crazy',
#   'rbg',
#   'merrick',
#   'garland',
#   'scotus',
#   'swap'],
#  ['south',
#   'korean',
#   'president',
#   'meets',
#   'north',
#   'korea',
#   'kim',
#   'jong',
#   'un',
#   'talk',
#   'trump',
#   'summit'],
#  ['michelle', 'ross', 'carson', 'wild', 'ride', 'rupaul', 'drag', 'race'],
#  ['possible',
#   'viking',
#   'find',
#   'could',
#   'rewrite',
#   'north',
#   'american',
#   'history'],
#  ['details',
#   'emerge',
#   'forgotten',
#   'murder',
#   'snared',
#   'attorney',
#   'highway',
#   'patrolmen'],
#  ['sean',
#   'spicer',
#   'says',
#   'donald',
#   'trump',
#   'champion',
#   'first',
#   'amendment'],
#  ['uncovered',
#   'california',
#   'community',
#   'college',
#   'students',
#   'quest',
#   'mental',
#   'health',
#   'services'],
#  ['debra', 'messing', 'want', 'freak', 'grace', 'revival', 'yet', 'update'],
#  ['6', 'real', 'reasons', 'happy', 'married'],
#  ['khloe',
#   'kardashian',
#   'says',
#   'one',
#   'cocaine',
#   'kylie',
#   'jenner',
#   'graduation',
#   'party'],
#  ['chewbacca', 'got', 'chewbacca', 'mom', 'mask'],
#  ['yet',
#   'another',
#   'donald',
#   'trump',
#   'pick',
#   'habit',
#   'spreading',
#   'dangerous',
#   'conspiracy',
#   'theories'],
#  ['explosion',
#   'fedex',
#   'facility',
#   'outside',
#   'san',
#   'antonio',
#   'may',
#   'linked',
#   'austin',
#   'bombings',
#   'fbi',
#   'says'],
#  ['cupid',
#   'cop',
#   'gave',
#   'roses',
#   'cards',
#   'valentine',
#   'day',
#   'instead',
#   'tickets'],
#  ['fox',
#   'news',
#   'host',
#   'disavows',
#   'internment',
#   'camps',
#   'panelists',
#   'suggest',
#   'rounding',
#   'muslims'],
#  ['reince', 'priebus', 'says', 'late', 'candidate', 'stop', 'trump'],
#  ['minnesota',
#   'café',
#   'charges',
#   '35',
#   'cent',
#   'fee',
#   'protest',
#   'minimum',
#   'wage',
#   'hike'],
#  ['american', 'dreamer', 'age', 'trump'],
#  ['hillary',
#   'clinton',
#   'celebrates',
#   'confederate',
#   'flag',
#   'removal',
#   'mlk',
#   'day',
#   'ceremony'],
#  ['david', 'brooks', 'obama', 'manhood', 'problem', 'middle', 'east'],
#  ['terrorists', 'attack', 'us'],
#  ['nypd', 'secretly', 'spying', 'cell', 'phones', 'since', '2008'],
#  ['republicans',
#   'urge',
#   'obama',
#   'administration',
#   'crack',
#   'sanctuary',
#   'cities'],
#  ['voters',
#   '14',
#   'states',
#   'navigating',
#   'rules',
#   'trying',
#   'cast',
#   'ballots'],
#  ['stop', 'complaining', 'evolution', 'text', 'language', 'period'],
#  ['communication', 'matters', 'getting', 'message'],
#  ['dozens', 'injured', 'trains', 'collide', 'pennsylvania'],
#  ['ed', 'sheeran', 'sang', 'chasing', 'cars', 'wedding', 'swooning'],
#  ['un', 'rebukes', 'trump', 'jerusalem', 'move', 'overwhelming', 'vote'],
#  ['father', 'day', 'tribute', 'family', 'man'],
#  ['professors', 'try', 'figure', 'bae', 'fleek', 'mean'],
#  ['house',
#   'republican',
#   'spending',
#   'bill',
#   'seeks',
#   'block',
#   'obama',
#   'carbon',
#   'rules'],
#  ['democrats', 'panic', 'one', 'poll', 'showing', 'donald', 'trump', 'ahead'],
#  ['humans', 'laying', 'welcome', 'mat', 'mosquitoes', 'diseases', 'carry'],
#  ['jennifer',
#   'lawrence',
#   'honored',
#   'robert',
#   'de',
#   'niro',
#   'glaad',
#   'media',
#   'awards',
#   'way',
#   'knows'],
#  ['11', 'unexpected', 'ways', 'use', 'grapefruit'],
#  ['14', 'photos', 'show', 'special', 'bond', 'moms', 'daughters'],
#  ['star', 'wars', 'fans', 'freaking', 'jedi', 'last', 'jedi', 'plural'],
#  ['jimmy', 'carter', 'learned', 'make', 'wife', 'rosalynn', 'full', 'partner'],
#  ['gop', 'congressman', 'complains', 'women', 'grill', 'obamacare', 'repeal'],
#  ['religious',
#   'leaders',
#   'groups',
#   'appalled',
#   'trump',
#   'immigration',
#   'orders'],
#  ['10', 'places', 'gone', '10', 'years', 'ago'],
#  ['chicago',
#   'top',
#   'prosecutor',
#   'not',
#   'try',
#   'officer',
#   'killed',
#   'laquan',
#   'mcdonald'],
#  ['big', 'eyes', 'quiet', 'feminist', 'ever', 'met'],
#  ['bloomberg',
#   'gadfly',
#   'debuts',
#   'bid',
#   'shake',
#   'financial',
#   'commentary',
#   'space'],
#  ['harry', 'reid', 'republicans', 'acting', 'puppets', 'nra'],
#  ['women',
#   'business',
#   'q',
#   'rebecca',
#   'henderson',
#   'group',
#   'president',
#   'randstad',
#   'professional',
#   'solutions'],
#  ['michelle', 'obama', 'explains', 'uncertain', 'terms', 'run', 'office'],
#  ['republican',
#   'food',
#   'stamp',
#   'bill',
#   'would',
#   'cut',
#   'benefits',
#   'not',
#   'size',
#   'government'],
#  ['russians', 'mint', 'trump', 'trust', 'coin', 'ahead', 'inauguration'],
#  ['kristen',
#   'wiig',
#   'fake',
#   'trailer',
#   'jimmy',
#   'kimmel',
#   'needs',
#   'made',
#   'real',
#   'movie'],
#  ['patients', 'limited', 'english', 'likely', 'return', 'er'],
#  ['dear', 'baby', 'boomers', 'step', 'aside'],
#  ['spend',
#   'cent',
#   'bitcoin',
#   'see',
#   'john',
#   'oliver',
#   'cryptocurrency',
#   'warning'],
#  ['celebrities', 'mourn', 'anne', 'meara', 'twitter', 'news', 'death'],
#  ['need', 'know', 'obamacare', 'enrollment', 'year'],
#  ['hope'],
#  ['science', 'backed', 'reason', 'see', 'therapist', 'morning'],
#  ['turkish', 'president', 'muslim', 'family', 'engage', 'birth', 'control'],
#  ['claire', 'danes', 'expecting', 'baby', 'number', 'two', 'hugh', 'dancy'],
#  ['vlogger',
#   'shamed',
#   'walmart',
#   'fitting',
#   'room',
#   'might',
#   'stretch',
#   'clothes'],
#  ['university',
#   'texas',
#   'echoes',
#   'confederate',
#   'past',
#   'reverberate',
#   'present'],
#  ['trump',
#   'hints',
#   'obamacare',
#   'replacement',
#   'would',
#   'look',
#   'nothing',
#   'like',
#   'republicans',
#   'mind'],
#  ['director',
#   'paul',
#   'feig',
#   'says',
#   'men',
#   'speak',
#   'weinstein',
#   'sexual',
#   'assault',
#   'allegations'],
#  ['mike',
#   'pence',
#   'takes',
#   'oath',
#   'office',
#   'country',
#   'next',
#   'vice',
#   'president'],
#  ['fight',
#   'obama',
#   'treasury',
#   'nominee',
#   'underscores',
#   'battles',
#   'within',
#   'democratic',
#   'party'],
#  ['big', 'myth', 'spot', 'narcissist'],
#  ['slushing', 'utah', 'end', 'ski', 'season'],
#  ['candidates', 'voters', 'think', 'actually', 'win', 'november'],
#  ['missing', 'maryland', 'toddler', 'body', 'found', 'ohio', 'creek'],
#  ['adele', 'celebrates', 'titanic', 'themed', '30th', 'birthday'],
#  ['texas',
#   'public',
#   'school',
#   'districts',
#   'may',
#   'store',
#   'not',
#   'trash',
#   'leftover',
#   'food'],
#  ['donald',
#   'trump',
#   'insists',
#   'complete',
#   'power',
#   'pardon',
#   'russia',
#   'probe',
#   'persists'],
#  ['syria',
#   'ceasefire',
#   'backed',
#   'russia',
#   'turkey',
#   'holds',
#   'initial',
#   'clashes'],
#  ['french', 'parliament', 'debates', 'deep', 'sleep', 'bill', 'end', 'life'],
#  ['reality',
#   'risk',
#   'reward',
#   'us',
#   'kids',
#   'tv',
#   'ripe',
#   'authenticity',
#   'autonomy'],
#  ['transcript',
#   'emails',
#   'show',
#   'tabloid',
#   'reporters',
#   'helped',
#   'harvey',
#   'weinstein',
#   'get',
#   'dirt',
#   'women'],
#  ['trump', 'america', 'not', 'shining', 'city', 'hill'],
#  ['photographer', 'assumes', 'endless', 'identities', 'mother', 'clothes'],
#  ['elevate', 'leadership', '2016'],
#  ['woman', 'face', 'halloween', 'dummy', 'gets', 'repeated', '911', 'calls'],
#  ['future', 'blurry'],
#  ['pg', 'rated', 'facebook', 'alternative', 'evangelical', 'christians'],
#  ['donald',
#   'trump',
#   'unqualified',
#   'president',
#   'majority',
#   'american',
#   'voters',
#   'say'],
#  ['missouri',
#   'democrats',
#   'filibuster',
#   '39',
#   'hours',
#   'stop',
#   'anti',
#   'gay',
#   'religious',
#   'freedom',
#   'bill'],
#  ['9', 'year', 'old', 'reporter', 'told', 'cute', 'landed', 'book', 'deal'],
#  ['craigslist', 'missed', 'connection', 'delightfully', 'feminist'],
#  ['three',
#   'chinese',
#   'tourists',
#   'dead',
#   'six',
#   'people',
#   'missing',
#   'borneo',
#   'shipwreck'],
#  ['happens', 'ask', 'arya', 'stark', 'write', 'yearbook', 'quote'],
#  ['rescue', 'animals', 'get', 'help', 'need', 'thanks', 'online', 'donations'],
#  ['john',
#   'legend',
#   'speaks',
#   'crack',
#   'system',
#   'caused',
#   'mass',
#   'incarceration'],
#  ['police',
#   'launch',
#   'investigation',
#   'video',
#   'appears',
#   'show',
#   'cop',
#   'shoving',
#   'man',
#   'wheelchair',
#   'street'],
#  ['judge', 'asked', 'keep', 'knees', 'together', 'resigns'],
#  ['white',
#   'house',
#   'prepares',
#   'send',
#   'congress',
#   '15',
#   'billion',
#   'spending',
#   'cuts',
#   'package'],
#  ['gop',
#   'race',
#   'heads',
#   'south',
#   'carolina',
#   'known',
#   'dirty',
#   'tricks',
#   'brawls'],
#  ['kindergartener', 'allegedly', 'barred', 'school', 'two', 'moms'],
#  ['george', 'trashes', 'bill', 'reilly', 'wise', 'not'],
#  ['ohio', 'voters', 'get', 'decide', 'legalizing', 'marijuana'],
#  ['best', 'ifttt', 'recipes', 'make', 'vacation'],
#  ['microsoft',
#   'debuts',
#   'surface',
#   'book',
#   'first',
#   'laptop',
#   'plus',
#   'gizmos'],
#  ['fourth', 'death', 'york', 'legionnaire', 'disease', 'outbreak'],
#  ['william',
#   'h',
#   'macy',
#   'ultimate',
#   'dad',
#   'moment',
#   'dancing',
#   'daughter',
#   'prom'],
#  ['warm', 'temperatures', 'bring', 'hot', 'deals', 'winter', 'gear'],
#  ['unapologetic', 'self', 'portraits', 'shatter', 'perceptions', 'disability'],
#  ['libraries', 'burning', 'sarajevo', 'mosul'],
#  ['realized', 'years', 'searching', 'soulmate'],
#  ['astoria', 'characters', 'charity', 'stager'],
#  ['trump',
#   'army',
#   'secretary',
#   'pick',
#   'victim',
#   'gay',
#   'gestapo',
#   'right',
#   'wing',
#   'activists',
#   'claim'],
#  ['drama', 'desks', 'way'],
#  ['wonderful', 'life', 'almost', 'racy', 'theaters'],
#  ['ariana', 'grande', 'performs', 'break', 'free', 'snl'],
#  ['2016', 'electorate'],
#  ['10', 'super', 'annoying', 'things', 'help', 'whine'],
#  ['teen',
#   'football',
#   'recruit',
#   'makes',
#   'bold',
#   'statement',
#   'black',
#   'lives',
#   'training',
#   'camp'],
#  ['10', 'illinois', 'safest', 'cities'],
#  ['mothers', 'precious', 'misunderstood', 'many', 'mothers', 'met'],
#  ['5', 'steps', 'get', 'shy', 'sociable'],
#  ['9', '11'],
#  ['california',
#   'marijuana',
#   'businesses',
#   'get',
#   'first',
#   'commercial',
#   'insurer'],
#  ['really', 'happens', 'infected', 'measles', 'one', 'chart'],
#  ['republicans', 'face', 'last', 'minute', 'doubts', 'tax', 'proposal'],
#  ['lgbt', 'activist', 'question', 'left', 'ben', 'carson', 'speechless'],
#  ['want', 'get', 'inked', 'seeing', 'tattoo', 'artist', 'masterful', 'work'],
#  ['mike', 'pence', 'says', 'stands', 'president', 'charlottesville'],
#  ['twitter',
#   'wins',
#   'dismissal',
#   'lawsuit',
#   'alleging',
#   'islamic',
#   'state',
#   'support',
#   'federal',
#   'judge'],
#  ['teacher',
#   'allegedly',
#   'shares',
#   'nude',
#   'photos',
#   'boob',
#   'job',
#   'students'],
#  ['young', 'democrats', 'prefer', 'bernie', 'sanders', 'poll', 'finds'],
#  ['almost',
#   '9',
#   'million',
#   'people',
#   'enroll',
#   'obamacare',
#   'despite',
#   'trump',
#   'sabotage',
#   'attempts'],
#  ['would',
#   'bernie',
#   'sanders',
#   'supporters',
#   'take',
#   '200',
#   '000',
#   'goldman',
#   'sachs',
#   'speech'],
#  ['best',
#   'chance',
#   'defeat',
#   'roy',
#   'moore',
#   'may',
#   'democratic',
#   'party',
#   'lie',
#   'low'],
#  ['14', 'snapshots', 'summed', 'parenthood', '2014'],
#  ['ryan', 'seacrest', 'sells', 'squad', 'goals', 'series', 'cbs'],
#  ['pope', 'francis', 'meeting', 'rohingya', 'refugees', 'wept'],
#  ['gop',
#   'sen',
#   'bob',
#   'corker',
#   'trump',
#   'demonstrated',
#   'stability',
#   'competence'],
#  ['love', 'first'],
#  ['trump',
#   'lawyers',
#   'dish',
#   'russia',
#   'probe',
#   'steakhouse',
#   'nyt',
#   'reporter',
#   'listens'],
#  ['man',
#   'proposal',
#   'boyfriend',
#   'musical',
#   'moment',
#   'need',
#   'see',
#   'believe'],
#  ['gay', 'high', 'school', 'legislators', 'care', 'health'],
#  ['fighting', 'monsters'],
#  ['surprise', 'surprise', 'christopher', 'nolan', 'not', 'fan', 'netflix'],
#  ['lin',
#   'manuel',
#   'miranda',
#   'raffling',
#   'hamilton',
#   'date',
#   'raise',
#   'money',
#   'immigrants'],
#  ['amanda', 'seyfried', 'gave', 'birth', 'first', 'child'],
#  ['refugee', 'blues'],
#  ['7',
#   'full',
#   'podcast',
#   'seasons',
#   'holiday',
#   'binge',
#   'listening',
#   'pleasure'],
#  ['watch',
#   'top',
#   'chef',
#   'michael',
#   'voltaggio',
#   'read',
#   'one',
#   'star',
#   'yelp',
#   'reviews'],
#  ['triple', 'amputee', 'dream', 'wedding', 'brings', 'community', 'together'],
#  ['rand', 'filibuster', 'two', 'fer'],
#  ['8',
#   'arab',
#   'cartoonists',
#   'fight',
#   'freedom',
#   'expression',
#   'every',
#   'day'],
#  ['policewoman', 'flashed', 'badge', 'cop', 'conference', 'report'],
#  ['ruth',
#   'bader',
#   'ginsburg',
#   'says',
#   'cooler',
#   'heads',
#   'prevail',
#   'supreme',
#   'court',
#   'vacancy'],
#  ['bp',
#   'clean',
#   'water',
#   'act',
#   'fines',
#   'smaller',
#   'gulf',
#   'states',
#   'thought'],
#  ['man',
#   'carrying',
#   'knife',
#   'bible',
#   'fatally',
#   'shot',
#   'st',
#   'louis',
#   'county',
#   'police'],
#  ['shot', 'survived', 'relive', 'worst', 'night', 'life'],
#  ['27', 'delicious', 'ways', 'vegan', 'holiday', 'feast'],
#  ['epic', '360', 'degree', 'photos', 'make', 'feel', 'like', 'vacation'],
#  ['britney',
#   'spears',
#   'receive',
#   'prestigious',
#   'honor',
#   'lgbtq',
#   'community',
#   'support'],
#  ['conservatives',
# ...
#  ['bathroom',
#   'bill',
#   'inspires',
#   'north',
#   'carolina',
#   'rep',
#   'come',
#   'bisexual'],
#  ['women',
#   'business',
#   'q',
#   'stephanie',
#   'teuwen',
#   'president',
#   'co',
#   'founder',
#   'teuwen',
#   'communications'],
#  ['taylor',
#   'hatala',
#   'larsen',
#   'thompson',
#   'run',
#   'world',
#   'killer',
#   'dance',
#   'routine'],
#  ['jon', 'snow', 'battling', 'white', 'walkers', 'wearing', 'ikea', 'rug'],
#  ['backed', 'syrian', 'militias', 'take', 'back', 'raqqa', 'isis'],
#  ['germany',
#   'arrests',
#   'three',
#   'islamic',
#   'state',
#   'members',
#   'connected',
#   'paris',
#   'attacks'],
#  ['pope', 'francis', 'thinks', 'spend', 'much', 'time', 'facebook'],
#  ['last', 'minute', 'super', 'bowl', 'party', 'décor'],
#  ['beautiful', 'might', 'count'],
#  ['world', 'dangerous', 'path', 'reopening', 'hikers'],
#  ['man',
#   'faced',
#   '20',
#   'years',
#   'marijuana',
#   'possession',
#   'freed',
#   'legal',
#   'battle'],
#  ['defiant',
#   'londoners',
#   'sit',
#   'street',
#   'ramadan',
#   'evening',
#   'meal',
#   'high',
#   'rise',
#   'fire'],
#  ['gay',
#   'marriage',
#   'finds',
#   'scant',
#   'mention',
#   'among',
#   'republicans',
#   'values',
#   'voter',
#   'summit'],
#  ['ed', 'sheeran', 'massive', 'lion', 'tattoo', 'chest', 'update'],
#  ['nuns',
#   'advocates',
#   'protest',
#   'planned',
#   'pipeline',
#   'erecting',
#   'chapel',
#   'path'],
#  ['5',
#   'year',
#   'old',
#   'cancer',
#   'becomes',
#   'belle',
#   'ball',
#   'magical',
#   'birthday'],
#  ['dangerous', 'delusional'],
#  ['crazy', 'cheap', 'deal', 'fly', '10', 'countries', '30', 'days', '160'],
#  ['talktome',
#   'mom',
#   'discuss',
#   'life',
#   'biggest',
#   'challenges',
#   'happiest',
#   'moments'],
#  ['hillary', 'clinton', 'barking', 'dog', 'impression', 'totally', 'paw'],
#  ['terrifying',
#   'tornado',
#   'gives',
#   'couple',
#   'proposal',
#   'story',
#   'never',
#   'forget'],
#  ['parents',
#   'loving',
#   'touching',
#   'letter',
#   'written',
#   'newborn',
#   'perspective'],
#  ['grindr', 'offers', 'reminders', 'users', 'get', 'regular', 'hiv', 'tests'],
#  ['conan',
#   'brien',
#   'receives',
#   'rough',
#   'reception',
#   'haiti',
#   'donald',
#   'trump'],
#  ['trump',
#   'reportedly',
#   'called',
#   'germans',
#   'bad',
#   'vowed',
#   'stop',
#   'german',
#   'car',
#   'sales'],
#  ['late',
#   'night',
#   'hosts',
#   'gave',
#   'donald',
#   'trump',
#   'best',
#   'gags',
#   '71st',
#   'birthday'],
#  ['scott', 'walker', 'terrible', 'good', 'bad', 'week'],
#  ['making',
#   'post',
#   'breakup',
#   'masterpiece',
#   'one',
#   'location',
#   'permit',
#   'time'],
#  ['fierce', 'frozen', 'themed', 'ball', 'team', 'photo', 'goes', 'viral'],
#  ['jessica',
#   'biel',
#   'says',
#   'son',
#   'silas',
#   'definitely',
#   'takes',
#   'dad',
#   'justin',
#   'timberlake'],
#  ['supreme', 'court', 'hear', 'challenge', 'public', 'sector', 'unions'],
#  ['live', 'good', 'life', 'mexican', 'retirement', 'paradise'],
#  ['world',
#   'prematurity',
#   'day',
#   '2014',
#   'taking',
#   'action',
#   'newborns',
#   'born',
#   'soon'],
#  ['notre',
#   'dame',
#   'terror',
#   'suspects',
#   'planned',
#   'attack',
#   'paris',
#   'train',
#   'station',
#   'france',
#   'says'],
#  ['dad', 'claims', 'kingdom', '7', 'year', 'old', 'real', 'princess'],
#  ['politicians',
#   'bash',
#   'donald',
#   'trump',
#   'use',
#   'pocahontas',
#   'slur',
#   'navajo',
#   'event'],
#  ['drink', 'go', 'green', 'pistachios'],
#  ['donald',
#   'trump',
#   'economy',
#   'gonna',
#   'explode',
#   'let',
#   'happen',
#   'quickly'],
#  ['enchanting',
#   'beauty',
#   'beast',
#   'proposal',
#   'pure',
#   'fairy',
#   'tale',
#   'magic'],
#  ['tina', 'frost', 'las', 'vegas', 'shooting', 'victim', 'wakes', 'coma'],
#  ['tilda', 'swinton', 'clip', 'bigger', 'splash', 'watch', 'anyway'],
#  ['get', 'bikini', 'body', 'without', 'buying', 'bikini', 'body', 'plan'],
#  ['chicago', 'go', '750', 'homicides'],
#  ['testing', 'teacher'],
#  ['anatomy', 'uncoupling'],
#  ['fox', 'news', 'meteorologist', 'slams', 'woman', 'said', 'legs', 'fat'],
#  ['every', 'tomboy', 'guide', 'modern', 'lady'],
#  ['nicolas',
#   'sarkozy',
#   'promises',
#   'nationwide',
#   'ban',
#   'burkinis',
#   'elected'],
#  ['comic',
#   'liz',
#   'miele',
#   'animated',
#   'series',
#   'damaged',
#   'celebrates',
#   'first',
#   'season'],
#  ['3', 'simple', 'steps', 'teaching', 'child', 'art', 'persistence'],
#  ['thursday',
#   'morning',
#   'email',
#   'justice',
#   'department',
#   'takes',
#   'aim',
#   'lgbtq',
#   'rights'],
#  ['best', 'men', 'sunglasses', 'looks', 'summer'],
#  ['college', 'degree', 'really', 'best', 'investment'],
#  ['6', 'older', 'celebs', 'stole', 'show', 'golden', 'globes'],
#  ['thank', 'america'],
#  ['rand', 'paul', 'eats', 'hoax', 'john', 'mccain', 'met', 'isis'],
#  ['seeing', 'going', 'want', 'run', 'banana', 'republic'],
#  ['snl',
#   'version',
#   'angela',
#   'merkel',
#   'not',
#   'happy',
#   'donald',
#   'trump',
#   'time',
#   'person',
#   'year'],
#  ['grab', 'wine', 'boxes', 'grace', 'back'],
#  ['modern', 'gym', 'manners', '8', 'etiquette', 'tips', 'workout'],
#  ['g', 'word', 'project', 'maps', 'hundreds', 'gender', 'stories'],
#  ['stephen', 'colbert', 'worried', 'citizenship', 'law', 'fox', 'news'],
#  ['today', 'parents', 'business', 'giving', 'kids', 'advice'],
#  ['hmm', 'may', 'link', 'vaccines', 'political', 'pandering'],
#  ['creating', 'drug'],
#  ['trump',
#   'tells',
#   'australia',
#   'prime',
#   'minister',
#   'hates',
#   'taking',
#   'refugees'],
#  ['mcdonald', 'caved', 'ton', 'pissed', 'rick', 'morty', 'fans'],
#  ['let', 'past', 'teacher'],
#  ['understood',
#   'father',
#   'daughter',
#   'relationship',
#   'father',
#   'passed',
#   'away'],
#  ['good', 'want'],
#  ['israeli',
#   'forces',
#   'kill',
#   'palestinian',
#   'youth',
#   'wielding',
#   'knife',
#   'checkpoint'],
#  ['best', 'decluttering', 'advice', 'heard'],
#  ['jetblue', 'offering', '49', 'flights', '2', 'day', 'flash', 'sale'],
#  ['shocking',
#   'nashville',
#   'cliffhanger',
#   'might',
#   'connie',
#   'britton',
#   'swan',
#   'song'],
#  ['russell', 'simmons', 'wants', 'trump', 'win', 'gop', 'nomination'],
#  ['monday',
#   'matters',
#   'adorable',
#   'kitten',
#   'dog',
#   'grow',
#   'together',
#   'white',
#   'house',
#   'celebrates',
#   'marriage',
#   'equality',
#   'psa',
#   'forgiveness'],
#  ['jimmy',
#   'kimmel',
#   'uses',
#   'theater',
#   'make',
#   'sense',
#   'donald',
#   'trump',
#   'border',
#   'troops',
#   'plan'],
#  ['running', 'past', 'read', 'magical', 'novel'],
#  ['could', 'see', 'michelle', 'obama', 'designs'],
#  ['iowa', 'supreme', 'court', 'strikes', 'telemedicine', 'abortion', 'ban'],
#  ['men', 'menstruated', 'would', 'periods', 'still', 'taboo'],
#  ['nbc',
#   'obtains',
#   'video',
#   'claiming',
#   'show',
#   'anti',
#   'isis',
#   'raid',
#   'killed',
#   'operative'],
#  ['marvel', 'releases', 'full', 'sized', 'teaser', 'ant', 'man', 'trailer'],
#  ['isis',
#   'laid',
#   'booby',
#   'traps',
#   'mosul',
#   'kill',
#   'injure',
#   'returning',
#   'civilians'],
#  ['education',
#   'department',
#   'tells',
#   'states',
#   'students',
#   'take',
#   'tests',
#   'lose',
#   'funding'],
#  ['trump', 'deal', 'democrats', 'gives', 'proof', 'fans', 'critics', 'alike'],
#  ['patton',
#   'oswalt',
#   'uses',
#   'icky',
#   'sauna',
#   'analogy',
#   'describe',
#   'donald',
#   'trump'],
#  ['texas', 'execute', 'man', 'murdering', 'boy', 'drinking', 'blood'],
#  ['baaaaack'],
#  ['mc', 'hammer', 'actually', 'afraid', 'hammers'],
#  ['4', 'couscous', 'recipes', 'every', 'meal', 'day'],
#  ['one', 'man', 'quest', 'document', 'highways', 'tore', 'city', 'apart'],
#  ['texas',
#   'officials',
#   'really',
#   'really',
#   'want',
#   'know',
#   'sandra',
#   'bland',
#   'marijuana',
#   'system'],
#  ['song', 'dance', 'leprosy', 'education'],
#  ['humane',
#   'society',
#   'board',
#   'members',
#   'quit',
#   'failure',
#   'oust',
#   'ceo',
#   'harassment'],
#  ['texas', 'moves', 'block', 'medicaid', 'funding', 'planned', 'parenthood'],
#  ['politicians',
#   'call',
#   'schneiderman',
#   'resign',
#   'physical',
#   'abuse',
#   'allegations'],
#  ['banksy',
#   'exhibit',
#   'inspires',
#   'ex',
#   'drug',
#   'addict',
#   'change',
#   'life',
#   'art'],
#  ['teacher', 'weary'],
#  ['dog',
#   'dies',
#   'united',
#   'flight',
#   'passenger',
#   'forced',
#   'put',
#   'carrier',
#   'overhead',
#   'bin'],
#  ['single', 'greatest', 'threat', 'national', 'security', 'donald', 'trump'],
#  ['bill', 'kristol', 'rand', 'paul', 'totally', 'overrated', '2016'],
#  ['fight', 'kid', 'give'],
#  ['washington', 'post', 'slimy', 'assault', 'gary', 'webb'],
#  ['5', 'interesting', 'restaurants', 'world'],
#  ['firefighters',
#   'gaining',
#   'ground',
#   'california',
#   'deadliest',
#   'ever',
#   'blazes'],
#  ['zenefits', 'told', 'employees', 'sex', 'stairwells'],
#  ['donald', 'trump', 'president', 'id'],
#  ['sleep', '8', 'top', 'reasons', 'insomnia'],
#  ['enigmatic', 'art', 'josef', 'koudelka'],
#  ['trump', 'says', 'muslim', 'judges', 'also', 'might', 'not', 'fair'],
#  ['trans',
#   'supermodel',
#   'outed',
#   '80s',
#   'lost',
#   'everything',
#   'became',
#   'pioneer'],
#  ['russia', 'military', 'talks', 'seen', 'syria', 'air', 'safety'],
#  ['hey', 'taylor', 'swift', 'caitlyn', 'jenner', 'got', 'call', 'kanye'],
#  ['eagles',
#   'death',
#   'metal',
#   'give',
#   'emotional',
#   'first',
#   'interview',
#   'since',
#   'paris',
#   'attack'],
#  ['chrome', 'extension', 'blocks', 'names', 'photos', 'mass', 'shooters'],
#  ['hillary', 'clinton', 'federal', 'reserve', 'plan', 'big', 'deal'],
#  ['rock', 'announced', '2020', 'presidential', 'bid', 'snl', 'kind'],
#  ['princess', 'charlotte', 'bonding', 'quite', 'lot', 'baby', 'brother'],
#  ['time', 'ripe', 'nonprofit', 'revolution'],
#  ['december', 'people'],
#  ['holiday', 'blues', 'spirituality', 'rescue'],
#  ['cadbury', 'chocolate', 'longer', 'imported', 'k', 'everyone', 'depressed'],
#  ['hobby', 'lobby', 'climate', 'change', 'gop', 'women', 'problem'],
#  ['opposition', 'protesters', 'rally', 'venezuela', 'president', 'maduro'],
#  ['warped',
#   'environmentalism',
#   'america',
#   'biggest',
#   'industrial',
#   'meat',
#   'producer'],
#  ['snoop', 'dogg', 'perform', 'dnc', 'courtesy', 'big', 'pharma'],
#  ['everyone', 'know', 'life', 'brain', 'injury'],
#  ['jared', 'leto', 'give', 'f', 'k', 'taylor', 'swift'],
#  ['republican',
#   'plan',
#   'higher',
#   'education',
#   'less',
#   'red',
#   'tape',
#   'less',
#   'money'],
#  ['happiest', 'man', 'america', 'still', 'happy'],
#  ['atheists',
#   'sue',
#   'pennsylvania',
#   'house',
#   'barred',
#   'giving',
#   'opening',
#   'invocations'],
#  ['law', 'lets', 'abused', 'animals', 'get', 'advocates', 'court'],
#  ['eric', 'swalwell', 'wins', 'election', 'bid'],
#  ['watch',
#   'first',
#   'trailer',
#   'bill',
#   'murray',
#   'murray',
#   'christmas',
#   'netflix',
#   'special',
#   'update'],
#  ['clean', 'closet', 'ditch', 'keep'],
#  ['king', 'solomon', 'story', 'really', 'mediating', 'judging'],
#  ['stephen', 'curry', 'thinks', 'warriors', 'lose', 'panthers'],
#  ['eagles',
#   'death',
#   'metal',
#   'singer',
#   'groveling',
#   '180',
#   'pathetic',
#   'parkland',
#   'survivors'],
#  ['part',
#   'two',
#   'engaged',
#   'employees',
#   'company',
#   '1',
#   'competitive',
#   'advantage'],
#  ['like', 'get', 'hands', 'stephen', 'colbert', 'col', 'bears'],
#  ['david',
#   'axelrod',
#   'view',
#   'inside',
#   'economic',
#   'storm',
#   'obama',
#   'inherited',
#   '2009'],
#  ['jon', 'stewart', '9', '11', 'responders', 'walk', 'halls', 'congress'],
#  ['crazy', 'thing', 'happened', 'quit', 'diet', 'coke'],
#  ['whoisdsharp', 'injects', 'viral', 'vine', 'violin', 'huffpost', '6x60'],
#  ['liberal',
#   'lion',
#   'donald',
#   'trump',
#   'least',
#   'favorite',
#   'court',
#   'lets',
#   'immigration'],
#  ['5', 'things', 'miss', 'married', 'life', 'divorced', 'mom'],
#  ['scientists', 'agree', 'effective', 'diet', 'weight', 'loss'],
#  ['battles', 'god', 'guns', 'gays', 'infiltrated', 'corporate', 'america'],
#  ['chrissy', 'teigen', 'thankful', 'filter', 'haters', 'instagram'],
#  ['scandalous', 'changes', 'could', 'coming', 'catholic', 'church'],
#  ['rip', 'ms', 'paint'],
#  ['lamar', 'odom', 'document', 'road', 'recovery', 'reality', 'series'],
#  ['let', 'get', 'business', 'meet', 'disney', 'mulan'],
#  ['oatmeal', 'breakfast', 'bars', 'packed', 'protein'],
#  ['7', 'things', 'learned', 'making', 'movie', 'pregnancy', 'loss'],
#  ['huffpost', 'pollster', 'polls', 'charts'],
#  ['hillary',
#   'clinton',
#   'wins',
#   'northern',
#   'mariana',
#   'islands',
#   'democratic',
#   'caucus'],
#  ['white',
#   'high',
#   'school',
#   'football',
#   'players',
#   'accused',
#   'coat',
#   'hanger',
#   'assault',
#   'black',
#   'disabled',
#   'teammate'],
#  ['rescue',
#   'team',
#   'saves',
#   'boy',
#   'dangling',
#   'ski',
#   'lift',
#   'dramatic',
#   'video'],
#  ['older', 'men', 'want', 'young', 'men', 'know', 'love'],
#  ['sunrise', 'vienna', 'austria'],
#  ['joyous',
#   'eid',
#   'somalia',
#   'ugaaso',
#   'abukar',
#   'boocow',
#   'instagram',
#   'photos',
#   'capture',
#   'celebrations',
#   'mogadishu'],
#  ['registered',
#   'child',
#   'sex',
#   'offenders',
#   'soon',
#   'convictions',
#   'noted',
#   'passports'],
#  ['senate', 'grapples', 'tax', 'cut', 'plan', 'impact', 'federal', 'deficit'],
#  ['obama', 'explains', 'difference', 'police', 'reform', 'war', 'cops'],
#  ['snl', 'praised', 'draw', 'muhammad', 'skit'],
#  ['elizabeth',
#   'warren',
#   'reveals',
#   'attend',
#   'donald',
#   'trump',
#   'inauguration'],
#  ['living', 'divorce', 'living', 'life'],
#  ['hi', 'tech', 'veggie', 'burger', 'good', 'convert', 'meat', 'eaters'],
#  ['not', 'interview'],
#  ['power',
#   'companies',
#   'could',
#   'use',
#   'drones',
#   'save',
#   'lives',
#   'cut',
#   'costs'],
#  ['7', 'essential', 'rules', 'long', 'lasting', 'marriage'],
#  ['tall', 'women', 'clogs', 'busts', 'stereotypes', 'height', 'gender'],
#  ['ocean', 'gentle', 'giant'],
#  ['climate', 'justice', 'peace'],
#  ['predictable',
#   'blowback',
#   'supporting',
#   'sectarian',
#   'authoritarianism',
#   'bahrain'],
#  ['must', 'increase', 'food', 'aid', 'time', 'famine'],
#  ['kerry', 'washington', 'artist', 'mean', 'less', 'voice'],
#  ['message', 'trump', 'regime', 'change', 'not', 'work', 'syria'],
#  ['state', 'department', 'releases', 'clinton', 'emails'],
#  ['man',
#   'tries',
#   'kill',
#   'spider',
#   'lighter',
#   'starts',
#   'gas',
#   'station',
#   'blaze'],
#  ['sweden', 'experiment', 'six', 'hour', 'workday'],
#  ['joan', 'moran', 'give', 'gift', 'time'],
#  ['loose',
#   'lipped',
#   'rudy',
#   'giuliani',
#   'not',
#   'represent',
#   'foreign',
#   'policy',
#   'warns',
#   'state',
#   'department'],
#  ['20', 'ways', 'not', 'talk', 'teenage', 'daughter', 'fix', 'things'],
#  ['spot', 'wrong', 'memphis', 'grizzlies', 'valentine', 'day', 'graphic'],
#  ['bill', 'moyers', 'departure', 'tv', 'leaves', 'huge', 'hole'],
#  ['make', 'best', 'holiday', 'season', 'money', 'buy'],
#  ['starting', 'unicorn', 'companies', 'fireeye'],
#  ['definitive', 'list', 'men', 'find', 'whole', 'foods'],
#  ['comedian',
#   'bashes',
#   'snl',
#   'not',
#   'casting',
#   'openly',
#   'gay',
#   'man',
#   '30',
#   'years'],
#  ['ivanka',
#   'trump',
#   'suggests',
#   'father',
#   'change',
#   'labor',
#   'laws',
#   'benefit',
#   'women'],
#  ['deputy',
#   'flipped',
#   'spring',
#   'valley',
#   'high',
#   'student',
#   'acted',
#   'reprehensibly',
#   'school',
#   'officials',
#   'say'],
#  ['thoughts', '54', 'blood', 'brothers', 'cabaret'],
#  ['slo',
#   'mo',
#   'watermelon',
#   'vs',
#   'mortar',
#   'another',
#   'kind',
#   'food',
#   'porn'],
#  ['many', 'women', 'take', 'change', 'cable', 'news', 'host'],
#  ['university', 'texas', 'professors', 'sue', 'block', 'guns', 'classrooms'],
#  ['literally',
#   'one',
#   'white',
#   'house',
#   'wants',
#   'defend',
#   'trump',
#   'tv',
#   'right'],
#  ['story'],
#  ['north', 'korea', 'internet', 'back', 'mass', 'cyber', 'attack'],
#  ['scooby', 'doo', 'movie', 'says', 'size', '8', 'curse'],
#  ['happy', 'valentine', 'day', 'weirdo'],
#  ['gunfire', 'erupts', 'ferguson', 'protester', 'struck', 'car'],
#  ['disorder', 'feels', 'like', 'awake', 'inside', 'corpse'],
#  ['wendy', 'williams', 'faints', 'live', 'tv', 'dressed', 'statue', 'liberty'],
#  ['prison', 'escapee', 'appears', 'court'],
#  ['end', 'innocence', 'taking', 'bystanding', 'bullying'],
#  ['trybeatingmelightly',
#   'shows',
#   'pakistani',
#   'women',
#   'stand',
#   'wife',
#   'beating',
#   'bill'],
#  ['put', 'summer', 'spin', 'regular', 'old', 'salsa'],
#  ['protester', 'heckles', 'joe', 'biden', 'son', 'death', 'brain', 'cancer'],
#  ['palestinians',
#   'suspicious',
#   'al',
#   'aqsa',
#   'surveillance',
#   'promoted',
#   'kerry'],
#  ['body', 'slams', 'ballots', 'belated', 'apologies', 'montana'],
#  ...]

# %%
# return only one list with the headlines tokens
todos_titulares_no_sarcasmo = list(itertools.chain(*todos_titulares_no_sarcasmo))
todos_titulares_no_sarcasmo[0:10]
# Out:
# ['former',
#  'versace',
#  'store',
#  'clerk',
#  'sues',
#  'secret',
#  'black',
#  'code',
#  'minority',
#  'shoppers']

# %%
# Dictionary with 
freq_no_sarcasmo = nltk.FreqDist(todos_titulares_no_sarcasmo)
freq_no_sarcasmo
# Out:
# FreqDist({'trump': 1446, 'donald': 458, 'not': 387, 'says': 349, 'women': 317, 'one': 268, 'year': 244, 'first': 242, 'world': 241, 'man': 241, ...})

# %%
df_no_sarcasmo = pd.DataFrame(list(freq_no_sarcasmo.items()), columns = ["Word","Frequency"])
df_no_sarcasmo.head()
# Out:
#       Word  Frequency
# 0   former         82
# 1  versace          1
# 2    store         14
# 3    clerk          5
# 4     sues         15

# %%
df_no_sarcasmo.sort_values('Frequency',ascending=False, inplace = True)
df_no_sarcasmo.head()
# Out:
#        Word  Frequency
# 46    trump       1446
# 229  donald        458
# 498     not        387
# 421    says        349
# 29    women        317

# %%
df_no_sarcasmo.reset_index(drop = True, inplace=True)
df_no_sarcasmo.head()
# Out:
#      Word  Frequency
# 0   trump       1446
# 1  donald        458
# 2     not        387
# 3    says        349
# 4   women        317

# %%
plt.figure(figsize = (15,8))
plot = sns.barplot(x  = df_no_sarcasmo.iloc[:30].Word, y = df_no_sarcasmo.iloc[:30].Frequency)
for item in plot.get_xticklabels():
    item.set_rotation(90)
plt.show()

# %% [markdown]
# #### Sarcasmo

# %%
dataset_sarcasmo = dataset[dataset.is_sarcastic==1]
dataset_sarcasmo.head()
# Out:
#                                          article_link  \
# 2   https://local.theonion.com/mom-starting-to-fea...
# 3   https://politics.theonion.com/boehner-just-wan...
# 8   https://politics.theonion.com/top-snake-handle...
# 15  https://entertainment.theonion.com/nuclear-bom...
# 16  https://www.theonion.com/cosby-lawyer-asks-why...
#
#                                              headline  is_sarcastic
# 2   mom starting to fear son's web series closest ...             1
# 3   boehner just wants wife to listen, not come up...             1
# 8   top snake handler leaves sinking huckabee camp...             1
# 15  nuclear bomb detonates during rehearsal for 's...             1
# 16  cosby lawyer asks why accusers didn't come for...             1

# %%
todos_titulares_sarcasmo = []
for i in range(dataset_sarcasmo.shape[0]):
    titular = dataset_sarcasmo.iloc[i].headline
    titular = nltk.tokenize.RegexpTokenizer("[\w]+").tokenize(titular)
    titular = [word for word in titular if word not in stopwords]
    titular = [word for word in titular if word not in filtrar]
    todos_titulares_sarcasmo.append(titular)

# %%
todos_titulares_sarcasmo = list(itertools.chain(*todos_titulares_sarcasmo))
todos_titulares_sarcasmo[0:10]
# Out:
# ['mom',
#  'starting',
#  'fear',
#  'son',
#  'web',
#  'series',
#  'closest',
#  'thing',
#  'grandchild',
#  'boehner']

# %%
freq_sarcasmo = nltk.FreqDist(todos_titulares_sarcasmo)
freq_sarcasmo
# Out:
# FreqDist({'man': 1154, 'area': 480, 'report': 426, 'not': 352, 'nation': 339, 'woman': 319, 'year': 308, 'one': 273, 'old': 267, 'time': 252, ...})

# %%
df_sarcasmo = pd.DataFrame(list(freq_sarcasmo.items()), columns = ["Word","Frequency"])
df_sarcasmo.head()
# Out:
#        Word  Frequency
# 0       mom        117
# 1  starting         32
# 2      fear         16
# 3       son         71
# 4       web          7

# %%
df_sarcasmo.sort_values('Frequency',ascending=False, inplace = True)
df_sarcasmo.head()
# Out:
#        Word  Frequency
# 31      man       1154
# 183    area        480
# 158  report        426
# 13      not        352
# 57   nation        339

# %%
df_sarcasmo.reset_index(drop = True, inplace=True)
df_sarcasmo.head()
# Out:
#      Word  Frequency
# 0     man       1154
# 1    area        480
# 2  report        426
# 3     not        352
# 4  nation        339

# %%
plt.figure(figsize = (15,8))
plot = sns.barplot(x  = df_sarcasmo.iloc[:30].Word, y = df_sarcasmo.iloc[:30].Frequency)
for item in plot.get_xticklabels():
    item.set_rotation(90)
plt.show()

# %% [markdown]
# ## 4. Stemming
# Por razones gramaticales muchas palabras pueden escribirse de manera distinta (debido a conjugación, género, número) pero tener el mismo significado para el texto. Por ejemplo si decimos "jugar", "jugando" o "juega", debido a como estan conjugadas, la computadora puede tratarlas como palabras distintas. Pero, en términos de significado, todas estan relacionadas al verbo Jugar. Muchas veces nos va a convenir unir todas estos términos en uno solo.
#
# Una de las manera de hacer esto es por "STEMMING". El Stemming es un proceso eurístico que recorta la terminación de las palabras, agrupándolas por su raiz. Reduzcamos la cantidad de palabras diferentes en nuestro dataset utilizando este proceso.
#
# a. Importar nuevamente el dataset completo

# %%
dataset = pd.read_json('Sarcasm_Headlines_Dataset.json', lines= True)
dataset.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %% [markdown]
# b. Tomar del `dataset` solo las columnas de interes

# %%
dataset=pd.concat([dataset.headline,dataset.is_sarcastic],axis=1)
dataset.dropna(axis=0,inplace=True)  # Si hay alguna nan, tiramos esa instancia
dataset.head()
# Out:
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %% [markdown]
# c. Antes de realizar el proceso de Stemming, vamos a normalizar el texto de la manera que ya estuvimos viendo. Le agregamos en este caso el uso de la libreria `re`, que nos permite sacar del texto todos los caracteres que no sean palabras. Notemos que hay veces que no conviene quitar estos caracteres ya que, por ejemplo, no podremos distiguir preguntas (?) o exclamaciones (!).

# %%
# Importamos esta libreria que nos permite reemplzar caracteres
import re

# Importamos la función que nos permite Stemmizar de nltk y definimos el stemmer
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# Traemos nuevamente las stopwords
stopwords = nltk.corpus.stopwords.words('english')
#stopword.remove('no')
#stopword.remove('not')

# %%
# Recorremos todos los titulos y le vamos aplicando la Normalizacion y luega el Stemming a cada uno
titular_list=[]
for titular in dataset.headline:
    # Vamos a reemplzar los caracteres que no sean leras por espacios
    titular=re.sub("[^a-zA-Z]"," ",str(titular))
    # Pasamos todo a minúsculas
    titular=titular.lower()
    # Tokenizamos para separar las palabras del titular
    titular=nltk.word_tokenize(titular)
    # Eliminamos las palabras de menos de 3 letras
    titular = [palabra for palabra in titular if len(palabra)>3]
    # Sacamos las Stopwords
    titular = [palabra for palabra in titular if not palabra in stopwords]
    
    ## Hasta acá Normalizamos, ahora a stemmizar
    
    # Aplicamos la funcion para buscar la raiz de las palabras
    titular=[stemmer.stem(palabra) for palabra in titular]
    # Por ultimo volvemos a unir el titular
    titular=" ".join(titular)
    
    # Vamos armando una lista con todos los titulares
    titular_list.append(titular)
    #dataset["titular_normalizado"] = titular_list

# %% [markdown]
# d. Agregamos al dataset una columna llamado `titular_stem` que contenga los titulares stemmizados

# %%
dataset["titular_stem"] = titular_list
dataset.tail()
# Out:
#                                                 headline  is_sarcastic  \
# 26704               american politics in moral free-fall             0
# 26705                            america's best 20 hikes             0
# 26706                              reparations and obama             0
# 26707  israeli ban targeting boycott supporters raise...             0
# 26708                  gourmet gifts for the foodie 2014             0
#
#                                         titular_stem
# 26704                 american polit moral free fall
# 26705                              america best hike
# 26706                                    repar obama
# 26707  isra target boycott support rais alarm abroad
# 26708                             gourmet gift foodi

# %% [markdown]
# e. Armamos un nuevo dataset llamado `dataset_stem` que contenga solo las columnas `titular_stem` e `is_sarcastic`

# %%
dataset_stem=pd.concat([dataset.titular_stem,dataset.is_sarcastic],axis=1)
dataset_stem.dropna(axis=0,inplace=True)  # Por si quedaron titulares vacios
dataset_stem.head()
# Out:
#                                         titular_stem  is_sarcastic
# 0  former versac store clerk sue secret black cod...             0
# 1  roseann reviv catch thorni polit mood better wors             0
# 2           start fear seri closest thing grandchild             1
# 3  boehner want wife listen come altern debt redu...             1
# 4               rowl wish snape happi birthday magic             0

# %% [markdown]
# ## 5. Lemmatization
#
# Otra manera de llevar distintas palabras a un raíz común en la que comparten un significado es mediante el procezo de 'Lemmatizar' el texto. Es similar al 'Stemming' pero un poco más educado, ya que intenta realizar el proceso teniendo en cuenta cuál es el rol que la palabra cumple en el texto. Esto quiere decir que su accionar será distinto si la palabra a lemmantizar está actuando como verbo, sustantivo, etc.
#
# Para usar las funciones que ofrece `nltk` para lemmantizar, tendremos primero que descargar la libreria `Wordnet` que se encuentra en la solapa 'corpora' y las librerias 'maxent_treebank_pos_' y 'averaged_perceptron_tagger' que se encuentra en la solapa 'Models'. Para eso ejecute la siguiente celda:

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# Importamos esta libreria que nos permite reemplzar caracteres
import re

# Importamos el lemmatizar de NLTK, y creamos el objeto
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# %% [markdown]
# Veamos cómo actúa el lemmatizer sobre una frase de ejemplo.

# %%
# Oracion que usaremos como ejemplo
frase = "He was running and eating at same time. He has bad habit of swimming after playing long hours in the Sun."

# Hay que regularizar el texto. Dejar solo letra, pasar a minúsculas y tokenizar:

# Sacamos todo lo que no sean letras
frase = re.sub("[^a-zA-Z]"," ",str(frase))
# Pasamos a minúsculas
frase = frase.lower()
# Tokenizamos
frase_tokens = nltk.word_tokenize(frase)

# Veamos como cambians las palabras al lemmatizar
print("{0:20}{1:20}".format("Word","Lemma"))
for palabra in frase_tokens:
    print ("{0:20}{1:20}".format(palabra,wordnet_lemmatizer.lemmatize(palabra)))
# Out:
# Word                Lemma
# he                  he
# was                 wa
# running             running
# and                 and
# eating              eating
# at                  at
# same                same
# time                time
# he                  he
# has                 ha
# bad                 bad
# habit               habit
# of                  of
# swimming            swimming
# after               after
# playing             playing
# long                long
# hours               hour
# in                  in
# the                 the
# sun                 sun

# %% [markdown]
# ¿Te sorprende lo que paso? No cambiaron casi nada (solo se fueron las "s" del final). El problema es que precisamos darle información extra al Lemmatizer, decirle qué rol está cumpliendo la palabra en la oración. Si se fijan en la documentación, esto se hace pasandole un argumento extra a la función llamado POS (Part Of Speech).
#
# Hay distintos metodos que intentan averiguar el rol que cumple una palabra en una oración. Nosotros vamos a utilizar uno que viene incorporado en NLTK llamado pos_tag.

# %%
print(nltk.pos_tag(frase_tokens))
# Out:
# [('he', 'PRP'), ('was', 'VBD'), ('running', 'VBG'), ('and', 'CC'), ('eating', 'VBG'), ('at', 'IN'), ('same', 'JJ'), ('time', 'NN'), ('he', 'PRP'), ('has', 'VBZ'), ('bad', 'JJ'), ('habit', 'NN'), ('of', 'IN'), ('swimming', 'NN'), ('after', 'IN'), ('playing', 'VBG'), ('long', 'JJ'), ('hours', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('sun', 'NN')]

# %% [markdown]
# Las etiquetas refieren al tipo de palabra. Vamos a definir una función para traducir estas etiquetas a los valores de POS que entiende `wordnet_lemmatizer`.

# %%
from nltk.corpus import wordnet

def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %% [markdown]
# Veamos finalmente como funciona en nuestro ejemplo.

# %%
frase_lemma = [wordnet_lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in nltk.word_tokenize(frase)]
tipo_palabra = [get_wordnet_pos(w) for w in nltk.word_tokenize(frase)]

# Veamos como cambiaron las palabras
print("{0:20}{1:20}{2:20}".format("Palabra:","Tipo:","Lemma:"))
for i in range(len(frase_tokens)):
    print ("{0:20}{1:20}{2:20}".format(frase_tokens[i],tipo_palabra[i],frase_lemma[i]))
# Out:
# Palabra:            Tipo:               Lemma:
# he                  n                   he
# was                 v                   be
# running             v                   run
# and                 n                   and
# eating              v                   eat
# at                  n                   at
# same                a                   same
# time                n                   time
# he                  n                   he
# has                 v                   have
# bad                 a                   bad
# habit               n                   habit
# of                  n                   of
# swimming            v                   swim
# after               n                   after
# playing             v                   play
# long                r                   long
# hours               n                   hour
# in                  n                   in
# the                 n                   the
# sun                 n                   sun

# %% [markdown]
# a. Ahora te toca aplicar todo esto a nuestro dataset. Vamos a volver a importarlo y hacer un procedimiento análogo al que hicimos para la parte de Stemming.

# %%
# Importamos el lemmatizar de NLTK, y creamos el objeto
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# Importamos esta libreria que nos permite reemplzar caracteres
import re

dataset = pd.read_json('Sarcasm_Headlines_Dataset.json', lines= True)
dataset = pd.concat([dataset.headline,dataset.is_sarcastic],axis=1)
dataset.dropna(axis=0,inplace=True)

# Traemos nuevamente las stopwords
stopwords = nltk.corpus.stopwords.words('english')
#stopword.remove('no')
#stopword.remove('not')

# %%
titular_list=[]
for titular in dataset.headline:
    # Vamos a reemplzar los caracteres que no sean leras por espacios
    titular=re.sub("[^a-zA-Z]"," ",str(titular))
    # Pasamos todo a minúsculas
    titular=titular.lower()
    # Tokenizamos para separar las palabras
    titular=nltk.word_tokenize(titular)
    
    # Aplicamos el Lemmatizer (Esto puede tardar un ratito)
    frase_lemma = [wordnet_lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in titular]
    
    
    # Eliminamos las palabras d emenos de 3 letras
    titular = [palabra for palabra in titular if len(palabra)>3]
    # Sacamos las Stopwords
    titular = [palabra for palabra in titular if not palabra in stopwords]
    
    # Por ultimo volvemos a unir el titular
    titular=" ".join(titular)
    #dataset["titular_normalizado"] = titular_list
    titular_list.append(titular)

# %%
dataset["titular_lemm"] = titular_list
dataset.tail()
# Out:
#                                                 headline  is_sarcastic  \
# 26704               american politics in moral free-fall             0
# 26705                            america's best 20 hikes             0
# 26706                              reparations and obama             0
# 26707  israeli ban targeting boycott supporters raise...             0
# 26708                  gourmet gifts for the foodie 2014             0
#
#                                             titular_lemm
# 26704                  american politics moral free fall
# 26705                                 america best hikes
# 26706                                  reparations obama
# 26707  israeli targeting boycott supporters raises al...
# 26708                               gourmet gifts foodie

# %% [markdown]
# b. Por último nos armamos un nuevo datasate llamado `dataset_lem` que tenga solo las columnas `titular_lemm` y `is_sarcastic`.

# %%
dataset_lemm = pd.concat([dataset.titular_lemm,dataset.is_sarcastic],axis=1)
dataset_lemm.dropna(axis=0,inplace=True)  # Por si quedaron titulares vacios
dataset_lemm.head()
# Out:
#                                         titular_lemm  is_sarcastic
# 0  former versace store clerk sues secret black c...             0
# 1  roseanne revival catches thorny political mood...             0
# 2      starting fear series closest thing grandchild             1
# 3  boehner wants wife listen come alternative deb...             1
# 4        rowling wishes snape happy birthday magical             0

# %% [markdown]
# **Para mirar**: toma algunos titulares al azar y compara su versión `dataset_lemm` y en `dataset_stem`. Explica.
#
# ## 6. Vectorizar
#
# Hasta ahora, tenemos un grupo de palabras por cada titular (bag of words), ya sea *lemmatizado* o *stemmizado*. ¿Te parece que esto servirá para entrenar modelos? La idea ahora es representar esta lista de palabras como un vector. Para esto vamos a utilizar la función `CountVectorizer` de Scikit-Learn. Esta función nos permite representar cada título por un vector con un `1` en las palabras que contiene y un `0` en las que no. Además, vamos a trabajar únicamente con las palabras que aparecen más veces en el texto, ya que las que aparecen una única vez o pocas veces no nos van a brindar información que se pueda generalizar.
#
# a. Tomamos la lista de palabras y el vector que nos dice si es o no sarcástico el título

# %%
# Tomamso la lista de palabras y el vector que nos dice si es o no sarcastico el titulo
list_titulos = list(dataset_lemm['titular_lemm'].values)
is_sarc = dataset_lemm['is_sarcastic'].values

## Para probar con Stemmizer:
#list_titulos = list(dataset_stem'titular_stem'].values)
#is_sarc = dataset_stem['is_sarcastic'].values

# %% [markdown]
# b. Preparamos el conversor de bag of words a vectores que traemos de sklearn. `CountVectorizer` posee varias funcionalidades que pueden determinarse a partir de parámetros. Les recomendamos fuertemente leer su documentación.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Usaremos solo las 1000 palabras con mas frecuencia en todo el corpus para generar los vectores
max_features=1000

# Es decir que cada instancia tendrá 1000 features
cou_vec=CountVectorizer(max_features=max_features) # stop_words="english" , ngram_range=(1, 2)

# %% [markdown]
# Notemos que desde `CountVectorizer` se pueden quitar las stopwords (algo que ya hicimos con `nltk`) e incluir los n_gramas automáticamente.
#
# c. Ahora sí, vamos generarnos los vectores para cada título a partir del corpus total.

# %%
matriz_titulos = cou_vec.fit_transform(list_titulos)

# Tomamos las palabras
all_words = cou_vec.get_feature_names()

# Vizualizamos las 50 palabras mas usadas
print("50 palabras mas usadas: ",all_words[0:50])
# Out:
# 50 palabras mas usadas:  ['abortion', 'abuse', 'accidentally', 'according', 'accused', 'across', 'action', 'activists', 'actor', 'actually', 'address', 'adds', 'administration', 'admits', 'adorable', 'advice', 'afghanistan', 'ahead', 'airport', 'album', 'allegations', 'almost', 'already', 'also', 'always', 'amazing', 'amazon', 'america', 'american', 'americans', 'amid', 'among', 'anniversary', 'announce', 'announces', 'another', 'anti', 'anyone', 'anything', 'apartment', 'apologizes', 'apparently', 'apple', 'archives', 'area', 'around', 'arrested', 'artist', 'asked', 'asking']

# %% [markdown]
# ## 7. Modelar
#
# Ahora sí estamos listos para usar todo nuestro conocimiento de modelos en este set de datos. Tengamos en cuenta que, dependiendo el número de palabras (features) que hayamos elegido, los modelos pueden tardar un rato en entrenarse.
#
# a. Primero, como siempre, separamos en test y train.

# %%
x = matriz_titulos.toarray()
y = is_sarc

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %% [markdown]
# Tambien definimos una función que nos permite plotear los resultados en una matriz de confusión.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def confusion(ytest,y_pred):
    names=["No Sarcastico","Sarcastico"]
    cm=confusion_matrix(ytest,y_pred)
    f,ax=plt.subplots(figsize=(5,5))
    sns.heatmap(cm,annot=True,linewidth=.5,linecolor="r",fmt=".0f",ax=ax)
    plt.xlabel("y_pred")
    plt.ylabel("y_true")
    ax.set_xticklabels(names)
    ax.set_yticklabels(names)
    plt.show()

    return

# %% [markdown]
# ### Naive Bayes
# a. Empecemos por un simple Naive Bayes para tener un benchmark de referencia para el accuracy.

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(xtrain,ytrain)
print("acc : ", nb.score(xtest,ytest))

# %% [markdown]
# b. Veamos cómo queda graficada la matriz de confusión:

# %%
y_pred=nb.predict(xtest)
confusion(ytest,y_pred)

# %% [markdown]
# ### Random Forest
# a. Veamos cómo funciona un random forest para predecir el sarcasmo de una nota en base a su titular.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

rf = RandomForestClassifier(n_estimators = 50, random_state=42)
rf.fit(xtrain,ytrain)
print("acc: ",rf.score(xtest,ytest))

# %% [markdown]
# b. Grafiquen su matriz de confusión:

# %%
y_pred=rf.predict(xtest)
confusion(ytest,y_pred)

# %% [markdown]
# c. Habíamos dicho que algo muy bueno de Random Forest era poder preguntarle por la importancia de los features que uso para clasificar. Veamos en este caso cuales son las palabras que mayormente determinan el sarcasmo de una nota para este clasificador.

# %%
# Le preguntamos la importancia de cada feature (cada palabra)
importances = rf.feature_importances_
# Tomamos la lista de palabras
all_words = cou_vec.get_feature_names()
columns = all_words

# Ordenamos por importnacia y tomamos las 20 primeras
indices = np.argsort(importances)[::-1]
indices = indices[:20]
selected_columns = [columns[i] for i in indices]
selected_importances = importances[indices]

# Por ultimo graficamos
plt.figure(figsize = (15,8))
sns.barplot(selected_columns, selected_importances)
plt.show()

# %% [markdown]
# ### SVM
# Por último vamos a utilizar uno de los modelos mas prometedores para este tipo de datos donde el numero de features es comparable al número de instancias: SVM.

# %% [markdown]
# a. Entrene un modelo de SVM Lineal y calcule su accuracy para C = 1.

# %%
# Notar que en vez de utilizar SVC, vamos a usar LinearSVC. 
# Para el Kernel Lineal, esta función es MUCHO mas rapida que la tradicional SVC.
from sklearn.svm import LinearSVC

svc = LinearSVC(C = 1)
svc.fit(xtrain,ytrain)
svc.score(xtest,ytest)

# %% [markdown]
# b. Grafiquen su matrz de confusión:

# %%
y_pred=svc.predict(xtest)
confusion(ytest,y_pred)

# %% [markdown]
# ## 7. Explora las posibilidades
#
# Si llegaste hasta acá, ya cuentas con todas las herramientas para poder explorar qué sucede con el poder predictivo cuando van cambiando la manera en que procesas y vectorizas el texto. Algunas sugerencias para explorar son las siguientes:
#
# 1. Prueba con Stemmizar en vez de lemmantizar
# 1. Cambia el numero de features que esta tomando.
# 1. Prueba con TF-IDF.
# 1. Incluye los 2-gramas. ¿Qué era eso?
# 1. Conserve los signos de exclamación y pregunta del texto.
